# %%
import pandas as pd
import numpy as np
from statsmodels.tools.eval_measures import rmse
from statsmodels.tsa.stattools import adfuller
import matplotlib.pylab as plt

# %% [markdown]
# # Lagi niestacjonarne

# %%
def calc_rmse(ts1, ts2):
    ts1u = ts1.dropna()
    ts2u = ts2[ts1u.index]
    return rmse(ts1u, ts2u)

def scale(ts):
    return ts/ts.max()

def find_best_lag(ts1, ts2, k=30):
    ts1_scaled = scale(ts1)
    ts2_scaled = scale(ts2)
    rmse_list = []
    for i in range(k):
        ts1_scaled_shift = ts1_scaled.shift(i)
        rmse_list.append(calc_rmse(ts1_scaled_shift, ts2_scaled))
    lag = rmse_list.index(min(rmse_list))
    
    return lag, rmse_list

def dft(df, column, d=0):
    ts = df[column].copy()
    if d!=0: ts = differentiated(ts, d)
    ts = ts.dropna()
    #Perform Augmented Dickey–Fuller test:
#     print('Results of Dickey Fuller Test:')
    dftest = adfuller(ts, autolag='AIC')

    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value

#     print(dfoutput)
    return dfoutput

# %%
df_lag = pd.read_csv('datasets/cale/zbior_do_lagow.csv', index_col=0)
variables = ['TensorFlow_', 'deep learning_', 'Artificial Intelligence_', 'Machine Learning_', 'neural network_', 'MXNet_', 'blockchain_news', 'GPU_news', 'gaming_news', 'BTC', 'SandP', 'NasdaqTech', 'ATVI_gaming', 'TTWO_gaming', 'UBSFY_gaming', 'fps_transformed_ffill', 'fps_transformed_interpolated', 'fps_interpolated_transformed', 'ATVI_gaming_rr', 'TTWO_gaming_rr', 'AMD_rr', 'SandP_rr', 'NasdaqTech_rr']
df_lag.head()
# Out:
#              open   high    low  close  Adj Close    volume  ATR  MOM  CCI  \
# 2012-01-03  14.30  14.40  14.01  14.04  12.981244  11701100  NaN  NaN  NaN
# 2012-01-04  14.05  14.26  13.92  14.20  13.129175   8684300  NaN  NaN  NaN
# 2012-01-05  14.13  14.78  14.07  14.71  13.600721  14088700  NaN  NaN  NaN
# 2012-01-06  14.70  14.71  14.37  14.54  13.443540  13331300  NaN  NaN  NaN
# 2012-01-09  14.55  14.82  14.44  14.54  13.443540  12706100  NaN  NaN  NaN
#
#             EMA  ...  ATVI_gaming_rr  TTWO_gaming_rr    AMD_rr  SandP_rr  \
# 2012-01-03  NaN  ...             NaN             NaN       NaN       NaN
# 2012-01-04  NaN  ...       -0.013788        0.005390 -0.007266  0.007260
# 2012-01-05  NaN  ...       -0.003701        0.032881 -0.001830  0.001578
# 2012-01-06  NaN  ...        0.004127        0.017301 -0.003666  0.000149
# 2012-01-09  NaN  ...        0.004110        0.010204  0.012879 -0.000082
#
#             NasdaqTech_rr  return ratio  fps_transformed_ffill  \
# 2012-01-03            NaN           NaN                    NaN
# 2012-01-04      -0.008122      0.011396                    NaN
# 2012-01-05       0.007389      0.035915                    NaN
# 2012-01-06       0.007123     -0.011557                    NaN
# 2012-01-09       0.006352      0.000000                    NaN
#
#             fps_transformed_0fill  fps_transformed_interpolated  \
# 2012-01-03                    0.0                           NaN
# 2012-01-04                    0.0                           NaN
# 2012-01-05                    0.0                           NaN
# 2012-01-06                    0.0                           NaN
# 2012-01-09                    0.0                           NaN
#
#             fps_interpolated_transformed
# 2012-01-03                           NaN
# 2012-01-04                           NaN
# 2012-01-05                           NaN
# 2012-01-06                           NaN
# 2012-01-09                           NaN
#
# [5 rows x 306 columns]

# %%
nonstationairy = []
stationairy = []
for var in variables:
    if dft(df_lag, var).loc['p-value'] < 0.05: stationairy.append(var)
    else: nonstationairy.append(var)

# %%
nonstationairy_lags = {}
for col in nonstationairy:
    lag, rmse_list = find_best_lag(df_lag[col], df_lag['close'])
    nonstationairy_lags[col] = (lag, rmse_list[lag])

# %%
nonstationairy_lags
# Out:
# {'TensorFlow_': (29, 0.1092558962244424),
#  'deep learning_': (29, 0.17194288935718868),
#  'Artificial Intelligence_': (29, 0.24346104169574315),
#  'Machine Learning_': (29, 0.15078105527635832),
#  'neural network_': (29, 0.30537558703484496),
#  'MXNet_': (29, 0.11632617023875003),
#  'blockchain_news': (0, 0.08023894850124773),
#  'GPU_news': (6, 0.18791021119177917),
#  'gaming_news': (29, 0.4447378360088254),
#  'BTC': (0, 0.22050114349282332),
#  'SandP': (29, 0.4738276052427284),
#  'NasdaqTech': (29, 0.322570178843348),
#  'ATVI_gaming': (29, 0.1789218461391596),
#  'TTWO_gaming': (0, 0.09655558673731462),
#  'UBSFY_gaming': (0, 0.07772626861299578),
#  'fps_transformed_ffill': (2, 0.2190667769608292),
#  'fps_transformed_interpolated': (0, 0.21525800430149886),
#  'fps_interpolated_transformed': (0, 0.2151711339282012)}

# %%
ml_czysty = pd.read_csv('datasets/cale/NVIDIA_dataset_machine_learning_adjustment.csv', index_col=0)

ekon_czysty = pd.read_csv('datasets/cale/NVIDIA_czysty_zbior_do_modeli_ekonometrycznych.csv', index_col=0)
ekon_columns = ekon_czysty.columns.drop('GPU_news', 'fps_interpolated_transformed').tolist()
ekon_columns
# Out:
# ['return ratio',
#  'ATR',
#  'MOM',
#  'CCI',
#  'EMA',
#  'RSI',
#  'Will_R',
#  'MFI',
#  'DX',
#  'PLUS_DM',
#  'PPO',
#  'AROONOSC',
#  'BOP',
#  'MINUS_DM',
#  'ULTOSC',
#  'AD',
#  'OBV',
#  'DEMA',
#  'HT_TRENDLINE',
#  'KAMA',
#  'MIDPOINT',
#  'MIDPRICE',
#  'SAR',
#  'SAREXT',
#  'T3',
#  'TEMA',
#  'TRIMA',
#  'WMA',
#  'ADX',
#  'ADXR',
#  'APO',
#  'CMO',
#  'MINUS_DI',
#  'PLUS_DI',
#  'ROC',
#  'ROCP',
#  'ROCR',
#  'ROCR100',
#  'ADOSC',
#  'NATR',
#  'TRANGE',
#  'AVGPRICE',
#  'MEDPRICE',
#  'TYPPRICE',
#  'WCLPRICE',
#  'HT_DCPERIOD',
#  'HT_DCPHASE',
#  'HT_TRENDMODE',
#  'CDL2CROWS',
#  'CDL3BLACKCROWS',
#  'CDL3INSIDE',
#  'CDL3LINESTRIKE',
#  'CDL3OUTSIDE',
#  'CDL3STARSINSOUTH',
#  'CDL3WHITESOLDIERS',
#  'CDLABANDONEDBABY',
#  'CDLADVANCEBLOCK',
#  'CDLBELTHOLD',
#  'CDLBREAKAWAY',
#  'CDLCLOSINGMARUBOZU',
#  'CDLCONCEALBABYSWALL',
#  'CDLCOUNTERATTACK',
#  'CDLDARKCLOUDCOVER',
#  'CDLDOJI',
#  'CDLDOJISTAR',
#  'CDLDRAGONFLYDOJI',
#  'CDLENGULFING',
#  'CDLEVENINGDOJISTAR',
#  'CDLEVENINGSTAR',
#  'CDLGAPSIDESIDEWHITE',
#  'CDLGRAVESTONEDOJI',
#  'CDLHAMMER',
#  'CDLHANGINGMAN',
#  'CDLHARAMI',
#  'CDLHARAMICROSS',
#  'CDLHIGHWAVE',
#  'CDLHIKKAKE',
#  'CDLHIKKAKEMOD',
#  'CDLHOMINGPIGEON',
#  'CDLIDENTICAL3CROWS',
#  'CDLINNECK',
#  'CDLINVERTEDHAMMER',
#  'CDLKICKING',
#  'CDLKICKINGBYLENGTH',
#  'CDLLADDERBOTTOM',
#  'CDLLONGLEGGEDDOJI',
#  'CDLLONGLINE',
#  'CDLMARUBOZU',
#  'CDLMATCHINGLOW',
#  'CDLMATHOLD',
#  'CDLMORNINGDOJISTAR',
#  'CDLMORNINGSTAR',
#  'CDLONNECK',
#  'CDLPIERCING',
#  'CDLRICKSHAWMAN',
#  'CDLRISEFALL3METHODS',
#  'CDLSEPARATINGLINES',
#  'CDLSHOOTINGSTAR',
#  'CDLSHORTLINE',
#  'CDLSPINNINGTOP',
#  'CDLSTALLEDPATTERN',
#  'CDLSTICKSANDWICH',
#  'CDLTAKURI',
#  'CDLTASUKIGAP',
#  'CDLTHRUSTING',
#  'CDLTRISTAR',
#  'CDLUNIQUE3RIVER',
#  'CDLUPSIDEGAP2CROWS',
#  'CDLXSIDEGAP3METHODS',
#  'BETA',
#  'CORREL',
#  'LINEARREG',
#  'LINEARREG_ANGLE',
#  'LINEARREG_INTERCEPT',
#  'LINEARREG_SLOPE',
#  'STDDEV',
#  'TSF',
#  'VAR',
#  'ADD',
#  'DIV',
#  'MAX',
#  'MAXINDEX',
#  'MIN',
#  'MININDEX',
#  'MULT',
#  'SUB',
#  'SUM',
#  'ATAN',
#  'CEIL',
#  'COS',
#  'COSH',
#  'EXP',
#  'FLOOR',
#  'LN',
#  'LOG10',
#  'SIN',
#  'SINH',
#  'SQRT',
#  'TAN',
#  'TANH',
#  'current ratio',
#  'long-term debt/capital',
#  'debt/equity ratio',
#  'gross_margin',
#  'operating_margin',
#  'ebig margin',
#  'pre-tax profit margin',
#  'net_profit_margin',
#  'asset_turnover',
#  'inventory_turnover_ratio',
#  'receiveable_turnover',
#  'days_sales_in_receivables',
#  'roe',
#  'return on tangible equity',
#  'roa',
#  'roi',
#  'book value per share',
#  'operating cash flow per share',
#  'free cash flow per share',
#  'nvidia_',
#  'GeForce_',
#  'gtx_',
#  'GPU_',
#  'AMD_',
#  'Intel_',
#  'deep learning_',
#  'Artificial Intelligence_',
#  'Machine Learning_',
#  'neural network_',
#  'Data Science_',
#  'natural language processing_',
#  'fintech_',
#  'Azure_',
#  'AWS_',
#  'Google Cloud_',
#  'TensorFlow_',
#  'PyTorch_',
#  'MXNet_',
#  'blockchain_',
#  'cryptocurrency_',
#  'bitcoin_',
#  'ethereum_',
#  'Bitcoin miner_',
#  'cryptocurrency miner_',
#  'gaming_',
#  'e-sport_',
#  'Battlefield_',
#  'Just Cause_',
#  "Assassin's Creed_",
#  'Hitman_',
#  'Far Cry_',
#  'Final Fantasy_',
#  'Forza Motorsport_',
#  'Call of Duty_',
#  'Witcher_',
#  'Fallout_',
#  'gaming PC_',
#  'Nvidia Shield_',
#  'GTA_',
#  'Python_',
#  'Twitch_',
#  'nvidia_news',
#  'gtx_news',
#  'AMD_news',
#  'deep learning_news',
#  'Artificial Intelligence_news',
#  'Data Science_news',
#  'fintech_news',
#  'AWS_news',
#  'blockchain_news',
#  'bitcoin_news',
#  'ethereum_news',
#  'gaming_news',
#  'e-sport_news',
#  'Battlefield_news',
#  'Just Cause_news',
#  "Assassin's Creed_news",
#  'Hitman_news',
#  'Far Cry_news',
#  'Final Fantasy_news',
#  'Forza Motorsport_news',
#  'Call of Duty_news',
#  'Witcher_news',
#  'Fallout_news',
#  'gaming PC_news',
#  'nvidia__scaled',
#  'GeForce__scaled',
#  'gtx__scaled',
#  'GPU__scaled',
#  'AMD__scaled',
#  'Intel__scaled',
#  'deep learning__scaled',
#  'Artificial Intelligence__scaled',
#  'Machine Learning__scaled',
#  'neural network__scaled',
#  'Data Science__scaled',
#  'natural language processing__scaled',
#  'fintech__scaled',
#  'Azure__scaled',
#  'AWS__scaled',
#  'Google Cloud__scaled',
#  'MXNet__scaled',
#  'Bitcoin miner__scaled',
#  'gaming__scaled',
#  'e-sport__scaled',
#  'Battlefield__scaled',
#  'Just Cause__scaled',
#  "Assassin's Creed__scaled",
#  'Hitman__scaled',
#  'Far Cry__scaled',
#  'Final Fantasy__scaled',
#  'Forza Motorsport__scaled',
#  'Call of Duty__scaled',
#  'Witcher__scaled',
#  'Fallout__scaled',
#  'gaming PC__scaled',
#  'GTA__scaled',
#  'Python__scaled',
#  'Twitch__scaled',
#  'nvidia_news_scaled',
#  'gtx_news_scaled',
#  'GPU_news_scaled',
#  'AMD_news_scaled',
#  'Artificial Intelligence_news_scaled',
#  'AWS_news_scaled',
#  'gaming_news_scaled',
#  'Battlefield_news_scaled',
#  'Just Cause_news_scaled',
#  "Assassin's Creed_news_scaled",
#  'Hitman_news_scaled',
#  'Far Cry_news_scaled',
#  'Final Fantasy_news_scaled',
#  'Forza Motorsport_news_scaled',
#  'Call of Duty_news_scaled',
#  'Witcher_news_scaled',
#  'Fallout_news_scaled',
#  'gaming PC_news_scaled',
#  'arxiv',
#  'BTC',
#  'AMD',
#  'SandP',
#  'NasdaqTech',
#  'ATVI_gaming',
#  'TTWO_gaming',
#  'UBSFY_gaming',
#  'super_gry',
#  'fps',
#  'NVIDIA_news_publikacja_(0, 1]',
#  'NVIDIA_news_publikacja_(1, 3]',
#  'NVIDIA_news_publikacja_(3, 6]',
#  'NVIDIA_news_publikacja_(6, 100]',
#  'NVIDIA_news_inni_o_nich_pisza_(0, 1]',
#  'NVIDIA_news_inni_o_nich_pisza_(1, 3]',
#  'NVIDIA_news_inni_o_nich_pisza_(3, 6]',
#  'ogloszenie_nowej_karty_(0, 1]',
#  'ogloszenie_nowej_karty_(1, 3]',
#  'ogloszenie_nowej_karty_(3, 20]',
#  'rolling variance',
#  'BTC_rr',
#  'ATVI_gaming_rr',
#  'TTWO_gaming_rr',
#  'UBSFY_gaming_rr',
#  'AMD_rr',
#  'SandP_rr',
#  'NasdaqTech_rr',
#  'BTC_rolling_variance',
#  'ATVI_gaming_rolling_variance',
#  'TTWO_gaming_rolling_variance',
#  'UBSFY_gaming_rolling_variance',
#  'AMD_rolling_variance',
#  'SandP_rolling_variance',
#  'NasdaqTech_rolling_variance',
#  'close',
#  'volume']

# %%
ekon_wszystkie = pd.DataFrame(ml_czysty['y_return_ratio'])
not_found = []
for col in ekon_columns:
    try:
        ekon_wszystkie[col+'_1_day_before'] = df_lag[col].shift(1)
    except:
        not_found.append(col)
        
for col in not_found:
    try:
        ekon_wszystkie[col+'_1_day_before'] = ml_czysty[col]
    except:
        print(col)

# %%
ekon_wszystkie.columns.tolist()
# Out:
# ['y_return_ratio',
#  'return ratio_1_day_before',
#  'ATR_1_day_before',
#  'MOM_1_day_before',
#  'CCI_1_day_before',
#  'EMA_1_day_before',
#  'RSI_1_day_before',
#  'Will_R_1_day_before',
#  'MFI_1_day_before',
#  'DX_1_day_before',
#  'PLUS_DM_1_day_before',
#  'PPO_1_day_before',
#  'AROONOSC_1_day_before',
#  'BOP_1_day_before',
#  'MINUS_DM_1_day_before',
#  'ULTOSC_1_day_before',
#  'AD_1_day_before',
#  'OBV_1_day_before',
#  'DEMA_1_day_before',
#  'HT_TRENDLINE_1_day_before',
#  'KAMA_1_day_before',
#  'MIDPOINT_1_day_before',
#  'MIDPRICE_1_day_before',
#  'SAR_1_day_before',
#  'SAREXT_1_day_before',
#  'T3_1_day_before',
#  'TEMA_1_day_before',
#  'TRIMA_1_day_before',
#  'WMA_1_day_before',
#  'ADX_1_day_before',
#  'ADXR_1_day_before',
#  'APO_1_day_before',
#  'CMO_1_day_before',
#  'MINUS_DI_1_day_before',
#  'PLUS_DI_1_day_before',
#  'ROC_1_day_before',
#  'ROCP_1_day_before',
#  'ROCR_1_day_before',
#  'ROCR100_1_day_before',
#  'ADOSC_1_day_before',
#  'NATR_1_day_before',
#  'TRANGE_1_day_before',
#  'AVGPRICE_1_day_before',
#  'MEDPRICE_1_day_before',
#  'TYPPRICE_1_day_before',
#  'WCLPRICE_1_day_before',
#  'HT_DCPERIOD_1_day_before',
#  'HT_DCPHASE_1_day_before',
#  'HT_TRENDMODE_1_day_before',
#  'CDL2CROWS_1_day_before',
#  'CDL3BLACKCROWS_1_day_before',
#  'CDL3INSIDE_1_day_before',
#  'CDL3LINESTRIKE_1_day_before',
#  'CDL3OUTSIDE_1_day_before',
#  'CDL3STARSINSOUTH_1_day_before',
#  'CDL3WHITESOLDIERS_1_day_before',
#  'CDLABANDONEDBABY_1_day_before',
#  'CDLADVANCEBLOCK_1_day_before',
#  'CDLBELTHOLD_1_day_before',
#  'CDLBREAKAWAY_1_day_before',
#  'CDLCLOSINGMARUBOZU_1_day_before',
#  'CDLCONCEALBABYSWALL_1_day_before',
#  'CDLCOUNTERATTACK_1_day_before',
#  'CDLDARKCLOUDCOVER_1_day_before',
#  'CDLDOJI_1_day_before',
#  'CDLDOJISTAR_1_day_before',
#  'CDLDRAGONFLYDOJI_1_day_before',
#  'CDLENGULFING_1_day_before',
#  'CDLEVENINGDOJISTAR_1_day_before',
#  'CDLEVENINGSTAR_1_day_before',
#  'CDLGAPSIDESIDEWHITE_1_day_before',
#  'CDLGRAVESTONEDOJI_1_day_before',
#  'CDLHAMMER_1_day_before',
#  'CDLHANGINGMAN_1_day_before',
#  'CDLHARAMI_1_day_before',
#  'CDLHARAMICROSS_1_day_before',
#  'CDLHIGHWAVE_1_day_before',
#  'CDLHIKKAKE_1_day_before',
#  'CDLHIKKAKEMOD_1_day_before',
#  'CDLHOMINGPIGEON_1_day_before',
#  'CDLIDENTICAL3CROWS_1_day_before',
#  'CDLINNECK_1_day_before',
#  'CDLINVERTEDHAMMER_1_day_before',
#  'CDLKICKING_1_day_before',
#  'CDLKICKINGBYLENGTH_1_day_before',
#  'CDLLADDERBOTTOM_1_day_before',
#  'CDLLONGLEGGEDDOJI_1_day_before',
#  'CDLLONGLINE_1_day_before',
#  'CDLMARUBOZU_1_day_before',
#  'CDLMATCHINGLOW_1_day_before',
#  'CDLMATHOLD_1_day_before',
#  'CDLMORNINGDOJISTAR_1_day_before',
#  'CDLMORNINGSTAR_1_day_before',
#  'CDLONNECK_1_day_before',
#  'CDLPIERCING_1_day_before',
#  'CDLRICKSHAWMAN_1_day_before',
#  'CDLRISEFALL3METHODS_1_day_before',
#  'CDLSEPARATINGLINES_1_day_before',
#  'CDLSHOOTINGSTAR_1_day_before',
#  'CDLSHORTLINE_1_day_before',
#  'CDLSPINNINGTOP_1_day_before',
#  'CDLSTALLEDPATTERN_1_day_before',
#  'CDLSTICKSANDWICH_1_day_before',
#  'CDLTAKURI_1_day_before',
#  'CDLTASUKIGAP_1_day_before',
#  'CDLTHRUSTING_1_day_before',
#  'CDLTRISTAR_1_day_before',
#  'CDLUNIQUE3RIVER_1_day_before',
#  'CDLUPSIDEGAP2CROWS_1_day_before',
#  'CDLXSIDEGAP3METHODS_1_day_before',
#  'BETA_1_day_before',
#  'CORREL_1_day_before',
#  'LINEARREG_1_day_before',
#  'LINEARREG_ANGLE_1_day_before',
#  'LINEARREG_INTERCEPT_1_day_before',
#  'LINEARREG_SLOPE_1_day_before',
#  'STDDEV_1_day_before',
#  'TSF_1_day_before',
#  'VAR_1_day_before',
#  'ADD_1_day_before',
#  'DIV_1_day_before',
#  'MAX_1_day_before',
#  'MAXINDEX_1_day_before',
#  'MIN_1_day_before',
#  'MININDEX_1_day_before',
#  'MULT_1_day_before',
#  'SUB_1_day_before',
#  'SUM_1_day_before',
#  'ATAN_1_day_before',
#  'CEIL_1_day_before',
#  'COS_1_day_before',
#  'COSH_1_day_before',
#  'EXP_1_day_before',
#  'FLOOR_1_day_before',
#  'LN_1_day_before',
#  'LOG10_1_day_before',
#  'SIN_1_day_before',
#  'SINH_1_day_before',
#  'SQRT_1_day_before',
#  'TAN_1_day_before',
#  'TANH_1_day_before',
#  'current ratio_1_day_before',
#  'long-term debt/capital_1_day_before',
#  'debt/equity ratio_1_day_before',
#  'gross_margin_1_day_before',
#  'operating_margin_1_day_before',
#  'ebig margin_1_day_before',
#  'pre-tax profit margin_1_day_before',
#  'net_profit_margin_1_day_before',
#  'asset_turnover_1_day_before',
#  'inventory_turnover_ratio_1_day_before',
#  'receiveable_turnover_1_day_before',
#  'days_sales_in_receivables_1_day_before',
#  'roe_1_day_before',
#  'return on tangible equity_1_day_before',
#  'roa_1_day_before',
#  'roi_1_day_before',
#  'book value per share_1_day_before',
#  'operating cash flow per share_1_day_before',
#  'free cash flow per share_1_day_before',
#  'nvidia__1_day_before',
#  'GeForce__1_day_before',
#  'gtx__1_day_before',
#  'GPU__1_day_before',
#  'AMD__1_day_before',
#  'Intel__1_day_before',
#  'deep learning__1_day_before',
#  'Artificial Intelligence__1_day_before',
#  'Machine Learning__1_day_before',
#  'neural network__1_day_before',
#  'Data Science__1_day_before',
#  'natural language processing__1_day_before',
#  'fintech__1_day_before',
#  'Azure__1_day_before',
#  'AWS__1_day_before',
#  'Google Cloud__1_day_before',
#  'TensorFlow__1_day_before',
#  'PyTorch__1_day_before',
#  'MXNet__1_day_before',
#  'blockchain__1_day_before',
#  'cryptocurrency__1_day_before',
#  'bitcoin__1_day_before',
#  'ethereum__1_day_before',
#  'Bitcoin miner__1_day_before',
#  'cryptocurrency miner__1_day_before',
#  'gaming__1_day_before',
#  'e-sport__1_day_before',
#  'Battlefield__1_day_before',
#  'Just Cause__1_day_before',
#  "Assassin's Creed__1_day_before",
#  'Hitman__1_day_before',
#  'Far Cry__1_day_before',
#  'Final Fantasy__1_day_before',
#  'Forza Motorsport__1_day_before',
#  'Call of Duty__1_day_before',
#  'Witcher__1_day_before',
#  'Fallout__1_day_before',
#  'gaming PC__1_day_before',
#  'Nvidia Shield__1_day_before',
#  'GTA__1_day_before',
#  'Python__1_day_before',
#  'Twitch__1_day_before',
#  'nvidia_news_1_day_before',
#  'gtx_news_1_day_before',
#  'AMD_news_1_day_before',
#  'deep learning_news_1_day_before',
#  'Artificial Intelligence_news_1_day_before',
#  'Data Science_news_1_day_before',
#  'fintech_news_1_day_before',
#  'AWS_news_1_day_before',
#  'blockchain_news_1_day_before',
#  'bitcoin_news_1_day_before',
#  'ethereum_news_1_day_before',
#  'gaming_news_1_day_before',
#  'e-sport_news_1_day_before',
#  'Battlefield_news_1_day_before',
#  'Just Cause_news_1_day_before',
#  "Assassin's Creed_news_1_day_before",
#  'Hitman_news_1_day_before',
#  'Far Cry_news_1_day_before',
#  'Final Fantasy_news_1_day_before',
#  'Forza Motorsport_news_1_day_before',
#  'Call of Duty_news_1_day_before',
#  'Witcher_news_1_day_before',
#  'Fallout_news_1_day_before',
#  'gaming PC_news_1_day_before',
#  'nvidia__scaled_1_day_before',
#  'GeForce__scaled_1_day_before',
#  'gtx__scaled_1_day_before',
#  'GPU__scaled_1_day_before',
#  'AMD__scaled_1_day_before',
#  'Intel__scaled_1_day_before',
#  'deep learning__scaled_1_day_before',
#  'Artificial Intelligence__scaled_1_day_before',
#  'Machine Learning__scaled_1_day_before',
#  'neural network__scaled_1_day_before',
#  'Data Science__scaled_1_day_before',
#  'natural language processing__scaled_1_day_before',
#  'fintech__scaled_1_day_before',
#  'Azure__scaled_1_day_before',
#  'AWS__scaled_1_day_before',
#  'Google Cloud__scaled_1_day_before',
#  'MXNet__scaled_1_day_before',
#  'Bitcoin miner__scaled_1_day_before',
#  'gaming__scaled_1_day_before',
#  'e-sport__scaled_1_day_before',
#  'Battlefield__scaled_1_day_before',
#  'Just Cause__scaled_1_day_before',
#  "Assassin's Creed__scaled_1_day_before",
#  'Hitman__scaled_1_day_before',
#  'Far Cry__scaled_1_day_before',
#  'Final Fantasy__scaled_1_day_before',
#  'Forza Motorsport__scaled_1_day_before',
#  'Call of Duty__scaled_1_day_before',
#  'Witcher__scaled_1_day_before',
#  'Fallout__scaled_1_day_before',
#  'gaming PC__scaled_1_day_before',
#  'GTA__scaled_1_day_before',
#  'Python__scaled_1_day_before',
#  'Twitch__scaled_1_day_before',
#  'nvidia_news_scaled_1_day_before',
#  'gtx_news_scaled_1_day_before',
#  'GPU_news_scaled_1_day_before',
#  'AMD_news_scaled_1_day_before',
#  'Artificial Intelligence_news_scaled_1_day_before',
#  'AWS_news_scaled_1_day_before',
#  'gaming_news_scaled_1_day_before',
#  'Battlefield_news_scaled_1_day_before',
#  'Just Cause_news_scaled_1_day_before',
#  "Assassin's Creed_news_scaled_1_day_before",
#  'Hitman_news_scaled_1_day_before',
#  'Far Cry_news_scaled_1_day_before',
#  'Final Fantasy_news_scaled_1_day_before',
#  'Forza Motorsport_news_scaled_1_day_before',
#  'Call of Duty_news_scaled_1_day_before',
#  'Witcher_news_scaled_1_day_before',
#  'Fallout_news_scaled_1_day_before',
#  'gaming PC_news_scaled_1_day_before',
#  'arxiv_1_day_before',
#  'BTC_1_day_before',
#  'AMD_1_day_before',
#  'SandP_1_day_before',
#  'NasdaqTech_1_day_before',
#  'ATVI_gaming_1_day_before',
#  'TTWO_gaming_1_day_before',
#  'UBSFY_gaming_1_day_before',
#  'super_gry_1_day_before',
#  'ATVI_gaming_rr_1_day_before',
#  'TTWO_gaming_rr_1_day_before',
#  'AMD_rr_1_day_before',
#  'SandP_rr_1_day_before',
#  'NasdaqTech_rr_1_day_before',
#  'close_1_day_before',
#  'volume_1_day_before',
#  'fps_1_day_before',
#  'NVIDIA_news_publikacja_(0, 1]_1_day_before',
#  'NVIDIA_news_publikacja_(1, 3]_1_day_before',
#  'NVIDIA_news_publikacja_(3, 6]_1_day_before',
#  'NVIDIA_news_publikacja_(6, 100]_1_day_before',
#  'NVIDIA_news_inni_o_nich_pisza_(0, 1]_1_day_before',
#  'NVIDIA_news_inni_o_nich_pisza_(1, 3]_1_day_before',
#  'NVIDIA_news_inni_o_nich_pisza_(3, 6]_1_day_before',
#  'ogloszenie_nowej_karty_(0, 1]_1_day_before',
#  'ogloszenie_nowej_karty_(1, 3]_1_day_before',
#  'ogloszenie_nowej_karty_(3, 20]_1_day_before',
#  'rolling variance_1_day_before',
#  'BTC_rr_1_day_before',
#  'UBSFY_gaming_rr_1_day_before',
#  'BTC_rolling_variance_1_day_before',
#  'ATVI_gaming_rolling_variance_1_day_before',
#  'TTWO_gaming_rolling_variance_1_day_before',
#  'UBSFY_gaming_rolling_variance_1_day_before',
#  'AMD_rolling_variance_1_day_before',
#  'SandP_rolling_variance_1_day_before',
#  'NasdaqTech_rolling_variance_1_day_before']

# %%
ekon_wszystkie['GPU_news_6_days_before'] = df_lag['GPU_news'].shift(6)
ekon_wszystkie['fps_interpolated_transformed_1_day_before'] = df_lag['fps_interpolated_transformed'].shift(1)
# ekon_wszystkie.to_csv('datasets/cale/ekonometryczne_wszystkie.csv')

# %%
ml = pd.read_csv('datasets/cale/NVIDIA_dataset_machine_learning_adjustment.csv', index_col=0)
ml.drop(['return ratio', 'return ratio_shift'], axis=1)
ml['GPU_news_shift_6'] = df_lag['GPU_news'].shift(7)
ml['fps_interpolated_transformed'] = df_lag['fps_interpolated_transformed'].shift(1)
ml['return_ratio'] = df_lag['return ratio'].shift(1)
ml['return_ratio_shift_1'] = df_lag['return ratio'].shift(2)
ml['return_ratio_shift_2'] = df_lag['return ratio'].shift(3)
ml['return_ratio_shift_3'] = df_lag['return ratio'].shift(4)
ml['return_ratio_shift_4'] = df_lag['return ratio'].shift(5)
ml['return_ratio_shift_5'] = df_lag['return ratio'].shift(6)
ml['return_ratio_shift_6'] = df_lag['return ratio'].shift(7)
ml['return_ratio_shift_7'] = df_lag['return ratio'].shift(8)
ml.to_csv('datasets/cale/ml_wszystkie.csv')

# %% [markdown]
# # Lagi stacjonarne

# %%
from statsmodels.tsa.stattools import adfuller
def differentiated(ts, d=1):
    ts = ts.copy()
    for i in range(d):
        ts = ts-ts.shift()
    return ts


def make_stationary(df, column, d=0):
    try:
        p_val = dft(df, column, d).loc['p-value']
        if p_val < 0.05: return d, df[column]
        else:
            d = d+1
            if d==4: return 0, None
            make_stationary(df, column, d)
        return d, differentiated(df[column], d)
    except: return 0, None

# %%
technical_analysis = [ 'ATR',
 'MOM',
 'CCI',
 'EMA',
 'RSI',
 'Will_R',
 'MFI',
 'DX',
 'PLUS_DM',
 'PPO',
 'AROONOSC',
 'BOP',
 'MINUS_DM',
 'ULTOSC',
 'AD',
 'OBV',
 'DEMA',
 'HT_TRENDLINE',
 'KAMA',
 'MIDPOINT',
 'MIDPRICE',
 'SAR',
 'SAREXT',
 'T3',
 'TEMA',
 'TRIMA',
 'WMA',
 'ADX',
 'ADXR',
 'APO',
 'CMO',
 'MINUS_DI',
 'PLUS_DI',
 'ROC',
 'ROCP',
 'ROCR',
 'ROCR100',
 'ADOSC',
 'NATR',
 'TRANGE',
 'AVGPRICE',
 'MEDPRICE',
 'TYPPRICE',
 'WCLPRICE',
 'HT_DCPERIOD',
 'HT_DCPHASE',
 'HT_TRENDMODE',
 'CDL2CROWS',
 'CDL3BLACKCROWS',
 'CDL3INSIDE',
 'CDL3LINESTRIKE',
 'CDL3OUTSIDE',
 'CDL3STARSINSOUTH',
 'CDL3WHITESOLDIERS',
 'CDLABANDONEDBABY',
 'CDLADVANCEBLOCK',
 'CDLBELTHOLD',
 'CDLBREAKAWAY',
 'CDLCLOSINGMARUBOZU',
 'CDLCONCEALBABYSWALL',
 'CDLCOUNTERATTACK',
 'CDLDARKCLOUDCOVER',
 'CDLDOJI',
 'CDLDOJISTAR',
 'CDLDRAGONFLYDOJI',
 'CDLENGULFING',
 'CDLEVENINGDOJISTAR',
 'CDLEVENINGSTAR',
 'CDLGAPSIDESIDEWHITE',
 'CDLGRAVESTONEDOJI',
 'CDLHAMMER',
 'CDLHANGINGMAN',
 'CDLHARAMI',
 'CDLHARAMICROSS',
 'CDLHIGHWAVE',
 'CDLHIKKAKE',
 'CDLHIKKAKEMOD',
 'CDLHOMINGPIGEON',
 'CDLIDENTICAL3CROWS',
 'CDLINNECK',
 'CDLINVERTEDHAMMER',
 'CDLKICKING',
 'CDLKICKINGBYLENGTH',
 'CDLLADDERBOTTOM',
 'CDLLONGLEGGEDDOJI',
 'CDLLONGLINE',
 'CDLMARUBOZU',
 'CDLMATCHINGLOW',
 'CDLMATHOLD',
 'CDLMORNINGDOJISTAR',
 'CDLMORNINGSTAR',
 'CDLONNECK',
 'CDLPIERCING',
 'CDLRICKSHAWMAN',
 'CDLRISEFALL3METHODS',
 'CDLSEPARATINGLINES',
 'CDLSHOOTINGSTAR',
 'CDLSHORTLINE',
 'CDLSPINNINGTOP',
 'CDLSTALLEDPATTERN',
 'CDLSTICKSANDWICH',
 'CDLTAKURI',
 'CDLTASUKIGAP',
 'CDLTHRUSTING',
 'CDLTRISTAR',
 'CDLUNIQUE3RIVER',
 'CDLUPSIDEGAP2CROWS',
 'CDLXSIDEGAP3METHODS',
 'BETA',
 'CORREL',
 'LINEARREG',
 'LINEARREG_ANGLE',
 'LINEARREG_INTERCEPT',
 'LINEARREG_SLOPE',
 'STDDEV',
 'TSF',
 'VAR',
 'ADD',
 'DIV',
 'MAX',
 'MAXINDEX',
 'MIN',
 'MININDEX',
 'MULT',
 'SUB',
 'SUM',
 'ATAN',
 'CEIL',
 'COS',
 'COSH',
 'EXP',
 'FLOOR',
 'LN',
 'LOG10',
 'SIN',
 'SINH',
 'SQRT',
 'TAN',
 'TANH']

# %%
nonstationairy_plus_technical = nonstationairy + technical_analysis

# %%
converted_to_stationairy = []
for col in nonstationairy_plus_technical:
    d, ts = make_stationary(df_lag, col)
    if d==0: continue
    ts.name = col+f'_{d}_diff'
    converted_to_stationairy.append(ts)
# Out:
# /home/michal/anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# /home/michal/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# /home/michal/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: divide by zero encountered in true_divide
#   return self.params / self.bse

# %%
stationairy_df = pd.concat(converted_to_stationairy, axis=1).join(df_lag[stationairy])
stationairy_df.head()
# Out:
#             TensorFlow__1_diff  deep learning__1_diff  \
# 2012-01-03                 NaN                    NaN
# 2012-01-04                 0.0               0.032258
# 2012-01-05                 0.0               0.032258
# 2012-01-06                 0.0               0.032258
# 2012-01-09                 0.0               0.096774
#
#             Artificial Intelligence__1_diff  Machine Learning__1_diff  \
# 2012-01-03                              NaN                       NaN
# 2012-01-04                         0.096774                  0.064516
# 2012-01-05                         0.096774                  0.064516
# 2012-01-06                         0.096774                  0.064516
# 2012-01-09                         0.290323                  0.193548
#
#             neural network__1_diff  MXNet__1_diff  blockchain_news_1_diff  \
# 2012-01-03                     NaN            NaN                     NaN
# 2012-01-04                0.129032            0.0                     0.0
# 2012-01-05                0.129032            0.0                     0.0
# 2012-01-06                0.129032            0.0                     0.0
# 2012-01-09                0.387097            0.0                     0.0
#
#             GPU_news_1_diff  gaming_news_1_diff  BTC_1_diff  ...  CEIL_1_diff  \
# 2012-01-03              NaN                 NaN         NaN  ...          NaN
# 2012-01-04        -0.064516           -0.322581       0.175  ...          0.0
# 2012-01-05        -0.064516           -0.322581       1.035  ...          0.0
# 2012-01-06        -0.064516           -0.322581       0.565  ...          0.0
# 2012-01-09        -0.193548           -0.967742      -0.105  ...          0.0
#
#             FLOOR_1_diff  LN_1_diff  LOG10_1_diff  SQRT_1_diff  \
# 2012-01-03           NaN        NaN           NaN          NaN
# 2012-01-04           0.0   0.011332      0.004921     0.021290
# 2012-01-05           0.0   0.035286      0.015324     0.067073
# 2012-01-06           0.0  -0.011624     -0.005048    -0.022227
# 2012-01-09           0.0   0.000000      0.000000     0.000000
#
#             ATVI_gaming_rr  TTWO_gaming_rr    AMD_rr  SandP_rr  NasdaqTech_rr
# 2012-01-03             NaN             NaN       NaN       NaN            NaN
# 2012-01-04       -0.013788        0.005390 -0.007266  0.007260      -0.008122
# 2012-01-05       -0.003701        0.032881 -0.001830  0.001578       0.007389
# 2012-01-06        0.004127        0.017301 -0.003666  0.000149       0.007123
# 2012-01-09        0.004110        0.010204  0.012879 -0.000082       0.006352
#
# [5 rows x 74 columns]

# %%
stationairy_lags = {}
for col in stationairy_df.columns:
    lag, rmse_list = find_best_lag(stationairy_df[col], df_lag['return ratio'])
    stationairy_lags[col] = (lag, rmse_list[lag])
# Out:
# /home/michal/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/michal/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
stationairy_lags = {k:v for k, v in stationairy_lags.items() if not np.isnan(v[1])}

# %%
stationairy_lags
# Out:
# {'TensorFlow__1_diff': (4, 0.1298794824289712),
#  'deep learning__1_diff': (4, 0.14658689193171912),
#  'Artificial Intelligence__1_diff': (19, 0.12330451243859841),
#  'Machine Learning__1_diff': (4, 0.18734240906674698),
#  'neural network__1_diff': (9, 0.21350003223585282),
#  'MXNet__1_diff': (9, 0.17174096666238003),
#  'blockchain_news_1_diff': (4, 0.138333183019606),
#  'GPU_news_1_diff': (17, 0.19304940811366036),
#  'gaming_news_1_diff': (2, 0.15041671884515803),
#  'BTC_1_diff': (29, 0.10120603990184197),
#  'SandP_1_diff': (0, 0.20056131850671866),
#  'NasdaqTech_1_diff': (0, 0.19946965127863228),
#  'ATVI_gaming_1_diff': (0, 0.11085281916069531),
#  'TTWO_gaming_1_diff': (0, 0.0970372634243754),
#  'UBSFY_gaming_1_diff': (0, 0.12976874031977245),
#  'fps_transformed_ffill_1_diff': (2, 0.0962432645030855),
#  'fps_transformed_interpolated_1_diff': (2, 0.08368482281963738),
#  'fps_interpolated_transformed_1_diff': (2, 0.08439060551927864),
#  'ATR_1_diff': (29, 0.10369089328398175),
#  'EMA_1_diff': (29, 0.26779451303822943),
#  'PLUS_DM_1_diff': (0, 0.07948137434522945),
#  'MINUS_DM_1_diff': (8, 0.09626876205751941),
#  'AD_1_diff': (0, 0.11460118477699821),
#  'OBV_1_diff': (0, 0.18400258020138321),
#  'DEMA_1_diff': (29, 0.2530165480038307),
#  'HT_TRENDLINE_1_diff': (29, 0.2680998843125545),
#  'KAMA_1_diff': (29, 0.14767740720615646),
#  'MIDPOINT_1_diff': (0, 0.11083933905113157),
#  'MIDPRICE_1_diff': (0, 0.12858429210605357),
#  'SAR_1_diff': (13, 0.11954720484476528),
#  'T3_1_diff': (29, 0.22292733855405125),
#  'TEMA_1_diff': (0, 0.22391085455303256),
#  'TRIMA_1_diff': (29, 0.2679076727174619),
#  'WMA_1_diff': (29, 0.26203544070759704),
#  'NATR_1_diff': (29, 0.09196742376896591),
#  'TRANGE_1_diff': (29, 0.10394399980363189),
#  'AVGPRICE_1_diff': (0, 0.128324760086223),
#  'MEDPRICE_1_diff': (0, 0.12384309351590894),
#  'TYPPRICE_1_diff': (0, 0.11057026240174492),
#  'WCLPRICE_1_diff': (0, 0.10346802480939701),
#  'LINEARREG_1_diff': (0, 0.20940994737842378),
#  'LINEARREG_INTERCEPT_1_diff': (29, 0.15145354136794548),
#  'STDDEV_1_diff': (29, 0.11507279423526355),
#  'TSF_1_diff': (0, 0.2120872499846729),
#  'ADD_1_diff': (0, 0.12384309351590543),
#  'MAX_1_diff': (0, 0.08605968764973367),
#  'MAXINDEX_1_diff': (0, 0.13321686425639204),
#  'MIN_1_diff': (0, 0.0994187627868772),
#  'MININDEX_1_diff': (19, 0.14727086615722104),
#  'MULT_1_diff': (0, 0.12173787616166762),
#  'SUB_1_diff': (29, 0.11887890724338449),
#  'SUM_1_diff': (29, 0.2489873448301316),
#  'ATAN_1_diff': (0, 0.11768888609803435),
#  'CEIL_1_diff': (0, 0.10364095830513056),
#  'FLOOR_1_diff': (0, 0.10355882381742272),
#  'LN_1_diff': (0, 0.011030227869935957),
#  'LOG10_1_diff': (0, 0.011030227869937133),
#  'SQRT_1_diff': (0, 0.046029632270980045),
#  'ATVI_gaming_rr': (0, 0.10704900375983717),
#  'TTWO_gaming_rr': (0, 0.13330921918095995),
#  'AMD_rr': (0, 0.09540053794189046),
#  'SandP_rr': (0, 0.1800740859415279),
#  'NasdaqTech_rr': (0, 0.20593257868333545)}

# %%
for col, tpl in stationairy_lags.items():
    if tpl[0]!=29:
        if tpl[0]==0: ekon_wszystkie[col+'_1_day_before'] = stationairy_df[col].shift(1)
        else: ekon_wszystkie[col+'_'+str(tpl[0])+'_days_before'] = stationairy_df[col].shift(tpl[0])

# %%
ekon_wszystkie.rename(columns={'return ratio_1_day_before': 'y_return_ratio_1_day_before'}, inplace=True)
ekon_wszystkie.columns.tolist()
# Out:
# ['y_return_ratio',
#  'y_return_ratio_1_day_before',
#  'ATR_1_day_before',
#  'MOM_1_day_before',
#  'CCI_1_day_before',
#  'EMA_1_day_before',
#  'RSI_1_day_before',
#  'Will_R_1_day_before',
#  'MFI_1_day_before',
#  'DX_1_day_before',
#  'PLUS_DM_1_day_before',
#  'PPO_1_day_before',
#  'AROONOSC_1_day_before',
#  'BOP_1_day_before',
#  'MINUS_DM_1_day_before',
#  'ULTOSC_1_day_before',
#  'AD_1_day_before',
#  'OBV_1_day_before',
#  'DEMA_1_day_before',
#  'HT_TRENDLINE_1_day_before',
#  'KAMA_1_day_before',
#  'MIDPOINT_1_day_before',
#  'MIDPRICE_1_day_before',
#  'SAR_1_day_before',
#  'SAREXT_1_day_before',
#  'T3_1_day_before',
#  'TEMA_1_day_before',
#  'TRIMA_1_day_before',
#  'WMA_1_day_before',
#  'ADX_1_day_before',
#  'ADXR_1_day_before',
#  'APO_1_day_before',
#  'CMO_1_day_before',
#  'MINUS_DI_1_day_before',
#  'PLUS_DI_1_day_before',
#  'ROC_1_day_before',
#  'ROCP_1_day_before',
#  'ROCR_1_day_before',
#  'ROCR100_1_day_before',
#  'ADOSC_1_day_before',
#  'NATR_1_day_before',
#  'TRANGE_1_day_before',
#  'AVGPRICE_1_day_before',
#  'MEDPRICE_1_day_before',
#  'TYPPRICE_1_day_before',
#  'WCLPRICE_1_day_before',
#  'HT_DCPERIOD_1_day_before',
#  'HT_DCPHASE_1_day_before',
#  'HT_TRENDMODE_1_day_before',
#  'CDL2CROWS_1_day_before',
#  'CDL3BLACKCROWS_1_day_before',
#  'CDL3INSIDE_1_day_before',
#  'CDL3LINESTRIKE_1_day_before',
#  'CDL3OUTSIDE_1_day_before',
#  'CDL3STARSINSOUTH_1_day_before',
#  'CDL3WHITESOLDIERS_1_day_before',
#  'CDLABANDONEDBABY_1_day_before',
#  'CDLADVANCEBLOCK_1_day_before',
#  'CDLBELTHOLD_1_day_before',
#  'CDLBREAKAWAY_1_day_before',
#  'CDLCLOSINGMARUBOZU_1_day_before',
#  'CDLCONCEALBABYSWALL_1_day_before',
#  'CDLCOUNTERATTACK_1_day_before',
#  'CDLDARKCLOUDCOVER_1_day_before',
#  'CDLDOJI_1_day_before',
#  'CDLDOJISTAR_1_day_before',
#  'CDLDRAGONFLYDOJI_1_day_before',
#  'CDLENGULFING_1_day_before',
#  'CDLEVENINGDOJISTAR_1_day_before',
#  'CDLEVENINGSTAR_1_day_before',
#  'CDLGAPSIDESIDEWHITE_1_day_before',
#  'CDLGRAVESTONEDOJI_1_day_before',
#  'CDLHAMMER_1_day_before',
#  'CDLHANGINGMAN_1_day_before',
#  'CDLHARAMI_1_day_before',
#  'CDLHARAMICROSS_1_day_before',
#  'CDLHIGHWAVE_1_day_before',
#  'CDLHIKKAKE_1_day_before',
#  'CDLHIKKAKEMOD_1_day_before',
#  'CDLHOMINGPIGEON_1_day_before',
#  'CDLIDENTICAL3CROWS_1_day_before',
#  'CDLINNECK_1_day_before',
#  'CDLINVERTEDHAMMER_1_day_before',
#  'CDLKICKING_1_day_before',
#  'CDLKICKINGBYLENGTH_1_day_before',
#  'CDLLADDERBOTTOM_1_day_before',
#  'CDLLONGLEGGEDDOJI_1_day_before',
#  'CDLLONGLINE_1_day_before',
#  'CDLMARUBOZU_1_day_before',
#  'CDLMATCHINGLOW_1_day_before',
#  'CDLMATHOLD_1_day_before',
#  'CDLMORNINGDOJISTAR_1_day_before',
#  'CDLMORNINGSTAR_1_day_before',
#  'CDLONNECK_1_day_before',
#  'CDLPIERCING_1_day_before',
#  'CDLRICKSHAWMAN_1_day_before',
#  'CDLRISEFALL3METHODS_1_day_before',
#  'CDLSEPARATINGLINES_1_day_before',
#  'CDLSHOOTINGSTAR_1_day_before',
#  'CDLSHORTLINE_1_day_before',
#  'CDLSPINNINGTOP_1_day_before',
#  'CDLSTALLEDPATTERN_1_day_before',
#  'CDLSTICKSANDWICH_1_day_before',
#  'CDLTAKURI_1_day_before',
#  'CDLTASUKIGAP_1_day_before',
#  'CDLTHRUSTING_1_day_before',
#  'CDLTRISTAR_1_day_before',
#  'CDLUNIQUE3RIVER_1_day_before',
#  'CDLUPSIDEGAP2CROWS_1_day_before',
#  'CDLXSIDEGAP3METHODS_1_day_before',
#  'BETA_1_day_before',
#  'CORREL_1_day_before',
#  'LINEARREG_1_day_before',
#  'LINEARREG_ANGLE_1_day_before',
#  'LINEARREG_INTERCEPT_1_day_before',
#  'LINEARREG_SLOPE_1_day_before',
#  'STDDEV_1_day_before',
#  'TSF_1_day_before',
#  'VAR_1_day_before',
#  'ADD_1_day_before',
#  'DIV_1_day_before',
#  'MAX_1_day_before',
#  'MAXINDEX_1_day_before',
#  'MIN_1_day_before',
#  'MININDEX_1_day_before',
#  'MULT_1_day_before',
#  'SUB_1_day_before',
#  'SUM_1_day_before',
#  'ATAN_1_day_before',
#  'CEIL_1_day_before',
#  'COS_1_day_before',
#  'COSH_1_day_before',
#  'EXP_1_day_before',
#  'FLOOR_1_day_before',
#  'LN_1_day_before',
#  'LOG10_1_day_before',
#  'SIN_1_day_before',
#  'SINH_1_day_before',
#  'SQRT_1_day_before',
#  'TAN_1_day_before',
#  'TANH_1_day_before',
#  'current ratio_1_day_before',
#  'long-term debt/capital_1_day_before',
#  'debt/equity ratio_1_day_before',
#  'gross_margin_1_day_before',
#  'operating_margin_1_day_before',
#  'ebig margin_1_day_before',
#  'pre-tax profit margin_1_day_before',
#  'net_profit_margin_1_day_before',
#  'asset_turnover_1_day_before',
#  'inventory_turnover_ratio_1_day_before',
#  'receiveable_turnover_1_day_before',
#  'days_sales_in_receivables_1_day_before',
#  'roe_1_day_before',
#  'return on tangible equity_1_day_before',
#  'roa_1_day_before',
#  'roi_1_day_before',
#  'book value per share_1_day_before',
#  'operating cash flow per share_1_day_before',
#  'free cash flow per share_1_day_before',
#  'nvidia__1_day_before',
#  'GeForce__1_day_before',
#  'gtx__1_day_before',
#  'GPU__1_day_before',
#  'AMD__1_day_before',
#  'Intel__1_day_before',
#  'deep learning__1_day_before',
#  'Artificial Intelligence__1_day_before',
#  'Machine Learning__1_day_before',
#  'neural network__1_day_before',
#  'Data Science__1_day_before',
#  'natural language processing__1_day_before',
#  'fintech__1_day_before',
#  'Azure__1_day_before',
#  'AWS__1_day_before',
#  'Google Cloud__1_day_before',
#  'TensorFlow__1_day_before',
#  'PyTorch__1_day_before',
#  'MXNet__1_day_before',
#  'blockchain__1_day_before',
#  'cryptocurrency__1_day_before',
#  'bitcoin__1_day_before',
#  'ethereum__1_day_before',
#  'Bitcoin miner__1_day_before',
#  'cryptocurrency miner__1_day_before',
#  'gaming__1_day_before',
#  'e-sport__1_day_before',
#  'Battlefield__1_day_before',
#  'Just Cause__1_day_before',
#  "Assassin's Creed__1_day_before",
#  'Hitman__1_day_before',
#  'Far Cry__1_day_before',
#  'Final Fantasy__1_day_before',
#  'Forza Motorsport__1_day_before',
#  'Call of Duty__1_day_before',
#  'Witcher__1_day_before',
#  'Fallout__1_day_before',
#  'gaming PC__1_day_before',
#  'Nvidia Shield__1_day_before',
#  'GTA__1_day_before',
#  'Python__1_day_before',
#  'Twitch__1_day_before',
#  'nvidia_news_1_day_before',
#  'gtx_news_1_day_before',
#  'AMD_news_1_day_before',
#  'deep learning_news_1_day_before',
#  'Artificial Intelligence_news_1_day_before',
#  'Data Science_news_1_day_before',
#  'fintech_news_1_day_before',
#  'AWS_news_1_day_before',
#  'blockchain_news_1_day_before',
#  'bitcoin_news_1_day_before',
#  'ethereum_news_1_day_before',
#  'gaming_news_1_day_before',
#  'e-sport_news_1_day_before',
#  'Battlefield_news_1_day_before',
#  'Just Cause_news_1_day_before',
#  "Assassin's Creed_news_1_day_before",
#  'Hitman_news_1_day_before',
#  'Far Cry_news_1_day_before',
#  'Final Fantasy_news_1_day_before',
#  'Forza Motorsport_news_1_day_before',
#  'Call of Duty_news_1_day_before',
#  'Witcher_news_1_day_before',
#  'Fallout_news_1_day_before',
#  'gaming PC_news_1_day_before',
#  'nvidia__scaled_1_day_before',
#  'GeForce__scaled_1_day_before',
#  'gtx__scaled_1_day_before',
#  'GPU__scaled_1_day_before',
#  'AMD__scaled_1_day_before',
#  'Intel__scaled_1_day_before',
#  'deep learning__scaled_1_day_before',
#  'Artificial Intelligence__scaled_1_day_before',
#  'Machine Learning__scaled_1_day_before',
#  'neural network__scaled_1_day_before',
#  'Data Science__scaled_1_day_before',
#  'natural language processing__scaled_1_day_before',
#  'fintech__scaled_1_day_before',
#  'Azure__scaled_1_day_before',
#  'AWS__scaled_1_day_before',
#  'Google Cloud__scaled_1_day_before',
#  'MXNet__scaled_1_day_before',
#  'Bitcoin miner__scaled_1_day_before',
#  'gaming__scaled_1_day_before',
#  'e-sport__scaled_1_day_before',
#  'Battlefield__scaled_1_day_before',
#  'Just Cause__scaled_1_day_before',
#  "Assassin's Creed__scaled_1_day_before",
#  'Hitman__scaled_1_day_before',
#  'Far Cry__scaled_1_day_before',
#  'Final Fantasy__scaled_1_day_before',
#  'Forza Motorsport__scaled_1_day_before',
#  'Call of Duty__scaled_1_day_before',
#  'Witcher__scaled_1_day_before',
#  'Fallout__scaled_1_day_before',
#  'gaming PC__scaled_1_day_before',
#  'GTA__scaled_1_day_before',
#  'Python__scaled_1_day_before',
#  'Twitch__scaled_1_day_before',
#  'nvidia_news_scaled_1_day_before',
#  'gtx_news_scaled_1_day_before',
#  'GPU_news_scaled_1_day_before',
#  'AMD_news_scaled_1_day_before',
#  'Artificial Intelligence_news_scaled_1_day_before',
#  'AWS_news_scaled_1_day_before',
#  'gaming_news_scaled_1_day_before',
#  'Battlefield_news_scaled_1_day_before',
#  'Just Cause_news_scaled_1_day_before',
#  "Assassin's Creed_news_scaled_1_day_before",
#  'Hitman_news_scaled_1_day_before',
#  'Far Cry_news_scaled_1_day_before',
#  'Final Fantasy_news_scaled_1_day_before',
#  'Forza Motorsport_news_scaled_1_day_before',
#  'Call of Duty_news_scaled_1_day_before',
#  'Witcher_news_scaled_1_day_before',
#  'Fallout_news_scaled_1_day_before',
#  'gaming PC_news_scaled_1_day_before',
#  'arxiv_1_day_before',
#  'BTC_1_day_before',
#  'AMD_1_day_before',
#  'SandP_1_day_before',
#  'NasdaqTech_1_day_before',
#  'ATVI_gaming_1_day_before',
#  'TTWO_gaming_1_day_before',
#  'UBSFY_gaming_1_day_before',
#  'super_gry_1_day_before',
#  'ATVI_gaming_rr_1_day_before',
#  'TTWO_gaming_rr_1_day_before',
#  'AMD_rr_1_day_before',
#  'SandP_rr_1_day_before',
#  'NasdaqTech_rr_1_day_before',
#  'close_1_day_before',
#  'volume_1_day_before',
#  'fps_1_day_before',
#  'NVIDIA_news_publikacja_(0, 1]_1_day_before',
#  'NVIDIA_news_publikacja_(1, 3]_1_day_before',
#  'NVIDIA_news_publikacja_(3, 6]_1_day_before',
#  'NVIDIA_news_publikacja_(6, 100]_1_day_before',
#  'NVIDIA_news_inni_o_nich_pisza_(0, 1]_1_day_before',
#  'NVIDIA_news_inni_o_nich_pisza_(1, 3]_1_day_before',
#  'NVIDIA_news_inni_o_nich_pisza_(3, 6]_1_day_before',
#  'ogloszenie_nowej_karty_(0, 1]_1_day_before',
#  'ogloszenie_nowej_karty_(1, 3]_1_day_before',
#  'ogloszenie_nowej_karty_(3, 20]_1_day_before',
#  'rolling variance_1_day_before',
#  'BTC_rr_1_day_before',
#  'UBSFY_gaming_rr_1_day_before',
#  'BTC_rolling_variance_1_day_before',
#  'ATVI_gaming_rolling_variance_1_day_before',
#  'TTWO_gaming_rolling_variance_1_day_before',
#  'UBSFY_gaming_rolling_variance_1_day_before',
#  'AMD_rolling_variance_1_day_before',
#  'SandP_rolling_variance_1_day_before',
#  'NasdaqTech_rolling_variance_1_day_before',
#  'GPU_news_6_days_before',
#  'fps_interpolated_transformed_1_day_before',
#  'TensorFlow__1_diff_4_days_before',
#  'deep learning__1_diff_4_days_before',
#  'Artificial Intelligence__1_diff_19_days_before',
#  'Machine Learning__1_diff_4_days_before',
#  'neural network__1_diff_9_days_before',
#  'MXNet__1_diff_9_days_before',
#  'blockchain_news_1_diff_4_days_before',
#  'GPU_news_1_diff_17_days_before',
#  'gaming_news_1_diff_2_days_before',
#  'SandP_1_diff_1_day_before',
#  'NasdaqTech_1_diff_1_day_before',
#  'ATVI_gaming_1_diff_1_day_before',
#  'TTWO_gaming_1_diff_1_day_before',
#  'UBSFY_gaming_1_diff_1_day_before',
#  'fps_transformed_ffill_1_diff_2_days_before',
#  'fps_transformed_interpolated_1_diff_2_days_before',
#  'fps_interpolated_transformed_1_diff_2_days_before',
#  'PLUS_DM_1_diff_1_day_before',
#  'MINUS_DM_1_diff_8_days_before',
#  'AD_1_diff_1_day_before',
#  'OBV_1_diff_1_day_before',
#  'MIDPOINT_1_diff_1_day_before',
#  'MIDPRICE_1_diff_1_day_before',
#  'SAR_1_diff_13_days_before',
#  'TEMA_1_diff_1_day_before',
#  'AVGPRICE_1_diff_1_day_before',
#  'MEDPRICE_1_diff_1_day_before',
#  'TYPPRICE_1_diff_1_day_before',
#  'WCLPRICE_1_diff_1_day_before',
#  'LINEARREG_1_diff_1_day_before',
#  'TSF_1_diff_1_day_before',
#  'ADD_1_diff_1_day_before',
#  'MAX_1_diff_1_day_before',
#  'MAXINDEX_1_diff_1_day_before',
#  'MIN_1_diff_1_day_before',
#  'MININDEX_1_diff_19_days_before',
#  'MULT_1_diff_1_day_before',
#  'ATAN_1_diff_1_day_before',
#  'CEIL_1_diff_1_day_before',
#  'FLOOR_1_diff_1_day_before',
#  'LN_1_diff_1_day_before',
#  'LOG10_1_diff_1_day_before',
#  'SQRT_1_diff_1_day_before']

# %%
ekon_wszystkie.to_csv('datasets/cale/ekonometryczne_wszystkie_2019_03_28__11_52_34.csv')

# %%
for col, tpl in stationairy_lags.items():
    if tpl[0]!=29:
        ml[col+('_shift_'+str(tpl[0]) if tpl[0]!=0 else "")] = stationairy_df[col].shift(tpl[0]+1)

# %%
ml.head()

# %%
ml.to_csv('datasets/cale/ml_wszystkie.csv')

# %%
ekon_stationairy = pd.DataFrame()
ekon_stationairy['y_return_ratio'] = df_lag['return ratio']
for col, tpl in stationairy_lags.items():
    if tpl[0]!=29:
        ekon_stationairy[col+('_shift_'+str(tpl[0]) if tpl[0]!=0 else "")] = stationairy_df[col].shift(tpl[0])

# %%
ekon_stationairy.head()

# %%
ml_stationairy = pd.DataFrame()
ml_stationairy['y_return_ratio'] = df_lag['return ratio']
ml_stationairy['return_ratio_shift_1'] = df_lag['return ratio'].shift(2)
ml_stationairy['return_ratio_shift_2'] = df_lag['return ratio'].shift(3)
ml_stationairy['return_ratio_shift_3'] = df_lag['return ratio'].shift(4)
ml_stationairy['return_ratio_shift_4'] = df_lag['return ratio'].shift(5)
ml_stationairy['return_ratio_shift_5'] = df_lag['return ratio'].shift(6)
ml_stationairy['return_ratio_shift_6'] = df_lag['return ratio'].shift(7)
ml_stationairy['return_ratio_shift_7'] = df_lag['return ratio'].shift(8)
for col, tpl in stationairy_lags.items():
    if tpl[0]!=29:
        ml_stationairy[col+('_shift_'+str(tpl[0]) if tpl[0]!=0 else "")] = stationairy_df[col].shift(tpl[0]+1)

# %%
ml_stationairy.head()

# %%
ekon_stationairy.to_csv('datasets/cale/ekonometryczne_stacjonarne.csv')
ml_stationairy.to_csv('datasets/cale/ml_stacjonarne.csv')
