# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt

import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout  
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
train = pd.read_csv('datasets/podzielone/ml/stacjonarne/train_ml.csv', index_col=0)
val1 = pd.read_csv('datasets/podzielone/ml/stacjonarne/valid1_ml.csv', index_col=0)
val2 = pd.read_csv('datasets/podzielone/ml/stacjonarne/valid2_ml.csv', index_col=0)
val3 = pd.read_csv('datasets/podzielone/ml/stacjonarne/valid3_ml.csv', index_col=0)
test = pd.read_csv('datasets/podzielone/ml/stacjonarne/test_ml.csv', index_col=0)




train.index = pd.to_datetime(train.index)
val1.index = pd.to_datetime(val1.index)
val2.index = pd.to_datetime(val2.index)
val3.index = pd.to_datetime(val3.index)
test.index = pd.to_datetime(test.index)


train["day_of_week"] = train.index.dayofweek
train["day_of_year"] = train.index.dayofweek
train["week"] = train.index.week
train["quarter"] = train.index.quarter
train["return_ratio"] = train.y_return_ratio.shift()

val1["day_of_week"] = val1.index.dayofweek
val1["day_of_year"] = val1.index.dayofweek
val1["week"] = val1.index.week
val1["quarter"] = val1.index.quarter
val1["return_ratio"] = val1.y_return_ratio.shift()

val2["day_of_week"] = val2.index.dayofweek
val2["day_of_year"] = val2.index.dayofweek
val2["week"] = val2.index.week
val2["quarter"] = val2.index.quarter
val2["return_ratio"] = val2.y_return_ratio.shift()

val3["day_of_week"] = val3.index.dayofweek
val3["day_of_year"] = val3.index.dayofweek
val3["week"] = val3.index.week
val3["quarter"] = val3.index.quarter
val3["return_ratio"] = val3.y_return_ratio.shift()

test["day_of_week"] = test.index.dayofweek
test["day_of_year"] = test.index.dayofweek
test["week"] = test.index.week
test["quarter"] = test.index.quarter
test["return_ratio"] = test.y_return_ratio.shift()

whole = pd.concat([train, val1, val2, val3, test]).asfreq('B', method='bfill').fillna(method='bfill')
val = pd.concat([val1, val2, val3]).asfreq('B', method='bfill').fillna(method='bfill')

train.columns=train.columns.str.replace('(','')
train.columns=train.columns.str.replace(']','')

val1.columns=val1.columns.str.replace('(','')
val1.columns=val1.columns.str.replace(']','')
val2.columns=val2.columns.str.replace('(','')
val2.columns=val2.columns.str.replace(']','')
val3.columns=val3.columns.str.replace('(','')
val3.columns=val3.columns.str.replace(']','')

val.columns=val.columns.str.replace('(','')
val.columns=val.columns.str.replace(']','')


train1 = train.asfreq('B', method='bfill').fillna(method='bfill')
train2 = pd.concat([train, val1]).asfreq('B', method='bfill').fillna(method='bfill')
train3 = pd.concat([train, val1, val2]).asfreq('B', method='bfill').fillna(method='bfill')

val1 = val1.asfreq('B', method='bfill').fillna(method='bfill')
val2 = val2.asfreq('B', method='bfill').fillna(method='bfill')
val3 = val3.asfreq('B', method='bfill').fillna(method='bfill')
test = test.asfreq('B', method='bfill').fillna(method='bfill')



display(train.head(3))
display(val1.head(3))
display(val2.head(3))
display(val3.head(3))
display(test.head(3))
display(whole.head(3))
# Out:
#             y_return_ratio  return_ratio_shift_1  return_ratio_shift_2  \
# 2012-07-02       -0.026773              0.007610              0.032207
# 2012-07-03        0.026022              0.043807              0.007610
# 2012-07-05       -0.010145             -0.026773              0.043807
#
#             return_ratio_shift_3  return_ratio_shift_4  return_ratio_shift_5  \
# 2012-07-02              0.011120             -0.031538              0.012461
# 2012-07-03              0.032207              0.011120             -0.031538
# 2012-07-05              0.007610              0.032207              0.011120
#
#             return_ratio_shift_6  return_ratio_shift_7  \
# 2012-07-02             -0.045353              0.015861
# 2012-07-03              0.012461             -0.045353
# 2012-07-05             -0.031538              0.012461
#
#             TensorFlow__diff_1_shift_4  deep learning__diff_1_shift_4  ...  \
# 2012-07-02                         0.0                       0.100000  ...
# 2012-07-03                         0.0                       0.033333  ...
# 2012-07-05                         0.0                       0.033333  ...
#
#             ATVI_gaming_rr  TTWO_gaming_rr    AMD_rr  SandP_rr  NasdaqTech_rr  \
# 2012-07-02        0.028212        0.015062  0.042357  0.011922       0.019487
# 2012-07-03        0.010553        0.000530  0.015901  0.013208       0.011249
# 2012-07-05        0.021303        0.017479  0.026957  0.004373       0.002684
#
#             day_of_week  day_of_year  week  quarter  return_ratio
# 2012-07-02            0            0    27        3           NaN
# 2012-07-03            1            1    27        3     -0.026773
# 2012-07-05            3            3    27        3      0.026022
#
# [3 rows x 61 columns]
#             y_return_ratio  return_ratio_shift_1  return_ratio_shift_2  \
# 2018-01-02        0.030233              0.001166             -0.001368
# 2018-01-03        0.065814             -0.019757              0.001166
# 2018-01-04        0.005271              0.030233             -0.019757
#
#             return_ratio_shift_3  return_ratio_shift_4  return_ratio_shift_5  \
# 2018-01-02              0.011113             -0.003165             -0.004624
# 2018-01-03             -0.001368              0.011113             -0.003165
# 2018-01-04              0.001166             -0.001368              0.011113
#
#             return_ratio_shift_6  return_ratio_shift_7  \
# 2018-01-02              0.003518             -0.009045
# 2018-01-03             -0.004624              0.003518
# 2018-01-04             -0.003165             -0.004624
#
#             TensorFlow__diff_1_shift_4  deep learning__diff_1_shift_4  ...  \
# 2018-01-02                   -0.032258                       0.096774  ...
# 2018-01-03                   -0.129032                       0.387097  ...
# 2018-01-04                   -0.032258                       0.096774  ...
#
#             ATVI_gaming_rr  TTWO_gaming_rr    AMD_rr  SandP_rr  NasdaqTech_rr  \
# 2018-01-02        0.001341        0.005920 -0.012784 -0.002025      -0.005463
# 2018-01-03        0.007407        0.017018  0.026379  0.003129       0.007868
# 2018-01-04        0.015722        0.019918  0.082243  0.005831       0.013572
#
#             day_of_week  day_of_year  week  quarter  return_ratio
# 2018-01-02            1            1     1        1      0.030233
# 2018-01-03            2            2     1        1      0.030233
# 2018-01-04            3            3     1        1      0.065814
#
# [3 rows x 61 columns]
#             y_return_ratio  return_ratio_shift_1  return_ratio_shift_2  \
# 2018-03-01       -0.040455             -0.002109              0.002643
# 2018-03-02        0.018647             -0.016500             -0.002109
# 2018-03-05       -0.003763             -0.040455             -0.016500
#
#             return_ratio_shift_3  return_ratio_shift_4  return_ratio_shift_5  \
# 2018-03-01              0.015610              0.002650             -0.030392
# 2018-03-02              0.002643              0.015610              0.002650
# 2018-03-05             -0.002109              0.002643              0.015610
#
#             return_ratio_shift_6  return_ratio_shift_7  \
# 2018-03-01              0.021490             -0.010791
# 2018-03-02             -0.030392              0.021490
# 2018-03-05              0.002650             -0.030392
#
#             TensorFlow__diff_1_shift_4  deep learning__diff_1_shift_4  ...  \
# 2018-03-01                    0.285714                      -0.071429  ...
# 2018-03-02                    0.285714                      -0.071429  ...
# 2018-03-05                    0.857143                      -0.214286  ...
#
#             ATVI_gaming_rr  TTWO_gaming_rr    AMD_rr  SandP_rr  NasdaqTech_rr  \
# 2018-03-01        0.004256       -0.004988 -0.007612 -0.010339      -0.004857
# 2018-03-02       -0.007588       -0.027815 -0.024627 -0.013666      -0.012133
# 2018-03-05        0.000413       -0.007027 -0.028146 -0.007927      -0.005995
#
#             day_of_week  day_of_year  week  quarter  return_ratio
# 2018-03-01            3            3     9        1     -0.040455
# 2018-03-02            4            4     9        1     -0.040455
# 2018-03-05            0            0    10        1      0.018647
#
# [3 rows x 61 columns]
#             y_return_ratio  return_ratio_shift_1  return_ratio_shift_2  \
# 2018-05-01        0.009960              0.004929              0.039509
# 2018-05-02       -0.003654             -0.006318              0.004929
# 2018-05-03        0.029517              0.009960             -0.006318
#
#             return_ratio_shift_3  return_ratio_shift_4  return_ratio_shift_5  \
# 2018-05-01             -0.020524             -0.011971             -0.021118
# 2018-05-02              0.039509             -0.020524             -0.011971
# 2018-05-03              0.004929              0.039509             -0.020524
#
#             return_ratio_shift_6  return_ratio_shift_7  \
# 2018-05-01             -0.001441             -0.031011
# 2018-05-02             -0.021118             -0.001441
# 2018-05-03             -0.011971             -0.021118
#
#             TensorFlow__diff_1_shift_4  deep learning__diff_1_shift_4  ...  \
# 2018-05-01                    0.066667                       0.033333  ...
# 2018-05-02                    0.066667                       0.033333  ...
# 2018-05-03                    0.066667                       0.033333  ...
#
#             ATVI_gaming_rr  TTWO_gaming_rr    AMD_rr  SandP_rr  NasdaqTech_rr  \
# 2018-05-01       -0.002038        0.007704 -0.016584 -0.002772      -0.008446
# 2018-05-02        0.013161        0.017689  0.000912 -0.006153      -0.001804
# 2018-05-03        0.017768        0.025826  0.005009 -0.001482       0.004321
#
#             day_of_week  day_of_year  week  quarter  return_ratio
# 2018-05-01            1            1    18        2      0.009960
# 2018-05-02            2            2    18        2      0.009960
# 2018-05-03            3            3    18        2     -0.003654
#
# [3 rows x 61 columns]
#             y_return_ratio  return_ratio_shift_1  return_ratio_shift_2  \
# 2018-07-02        0.022541              0.021806             -0.025910
# 2018-07-03       -0.022292             -0.016441              0.021806
# 2018-07-04        0.024869              0.022541             -0.016441
#
#             return_ratio_shift_3  return_ratio_shift_4  return_ratio_shift_5  \
# 2018-07-02              0.012002             -0.047141             -0.023959
# 2018-07-03             -0.025910              0.012002             -0.047141
# 2018-07-04              0.021806             -0.025910              0.012002
#
#             return_ratio_shift_6  return_ratio_shift_7  \
# 2018-07-02             -0.019824              0.008225
# 2018-07-03             -0.023959             -0.019824
# 2018-07-04             -0.047141             -0.023959
#
#             TensorFlow__diff_1_shift_4  deep learning__diff_1_shift_4  ...  \
# 2018-07-02                   -0.400000                      -0.100000  ...
# 2018-07-03                   -0.133333                      -0.033333  ...
# 2018-07-04                   -0.133333                      -0.033333  ...
#
#             ATVI_gaming_rr  TTWO_gaming_rr    AMD_rr  SandP_rr  NasdaqTech_rr  \
# 2018-07-02        0.018332        0.022284  0.007958  0.005633       0.010789
# 2018-07-03       -0.000786        0.002361 -0.014474 -0.002542      -0.001850
# 2018-07-04        0.006027        0.001725  0.008344  0.002730       0.005586
#
#             day_of_week  day_of_year  week  quarter  return_ratio
# 2018-07-02            0            0    27        3      0.022541
# 2018-07-03            1            1    27        3      0.022541
# 2018-07-04            3            3    27        3     -0.022292
#
# [3 rows x 61 columns]
#             y_return_ratio  return_ratio_shift_1  return_ratio_shift_2  \
# 2012-07-02       -0.026773              0.007610              0.032207
# 2012-07-03        0.026022              0.043807              0.007610
# 2012-07-04       -0.010145             -0.026773              0.043807
#
#             return_ratio_shift_3  return_ratio_shift_4  return_ratio_shift_5  \
# 2012-07-02              0.011120             -0.031538              0.012461
# 2012-07-03              0.032207              0.011120             -0.031538
# 2012-07-04              0.007610              0.032207              0.011120
#
#             return_ratio_shift_6  return_ratio_shift_7  \
# 2012-07-02             -0.045353              0.015861
# 2012-07-03              0.012461             -0.045353
# 2012-07-04             -0.031538              0.012461
#
#             TensorFlow__diff_1_shift_4  deep learning__diff_1_shift_4  ...  \
# 2012-07-02                         0.0                       0.100000  ...
# 2012-07-03                         0.0                       0.033333  ...
# 2012-07-04                         0.0                       0.033333  ...
#
#             ATVI_gaming_rr  TTWO_gaming_rr    AMD_rr  SandP_rr  NasdaqTech_rr  \
# 2012-07-02        0.028212        0.015062  0.042357  0.011922       0.019487
# 2012-07-03        0.010553        0.000530  0.015901  0.013208       0.011249
# 2012-07-04        0.021303        0.017479  0.026957  0.004373       0.002684
#
#             day_of_week  day_of_year  week  quarter  return_ratio
# 2012-07-02            0            0    27        3     -0.026773
# 2012-07-03            1            1    27        3     -0.026773
# 2012-07-04            3            3    27        3      0.026022
#
# [3 rows x 61 columns]

# %%
S = [(train1, val1), (train2, val2), (train3, val3)]

# %%
target = "y_return_ratio"

analiza_techniczna = [ 'PLUS_DM_diff_1',
 'MINUS_DM_diff_1_shift_8',
 'AD_diff_1',
 'OBV_diff_1',
 'MIDPOINT_diff_1',
 'MIDPRICE_diff_1',
 'SAR_diff_1_shift_13',
 'TEMA_diff_1',
 'AVGPRICE_diff_1',
 'MEDPRICE_diff_1',
 'TYPPRICE_diff_1',
 'WCLPRICE_diff_1',
 'LINEARREG_diff_1',
 'TSF_diff_1',
 'ADD_diff_1',
 'MAX_diff_1',
 'MAXINDEX_diff_1',
 'MIN_diff_1',
 'MININDEX_diff_1_shift_19',
 'MULT_diff_1',
 'ATAN_diff_1',
 'CEIL_diff_1',
 'FLOOR_diff_1',
 'LN_diff_1',
 'LOG10_diff_1',
 'SQRT_diff_1',]



google_trends = ['TensorFlow__diff_1_shift_4',
 'deep learning__diff_1_shift_4',
 'Artificial Intelligence__diff_1_shift_19',
 'Machine Learning__diff_1_shift_4',
 'neural network__diff_1_shift_9',
 'MXNet__diff_1_shift_9',
 'blockchain_news_diff_1_shift_4',
 'GPU_news_diff_1_shift_17',
 'gaming_news_diff_1_shift_2',]


rynki_3 = ['SandP_diff_1',
 'NasdaqTech_diff_1',
 'ATVI_gaming_diff_1',
 'TTWO_gaming_diff_1',
 'UBSFY_gaming_diff_1',
 'fps_transformed_ffill_diff_1_shift_2',
 'fps_transformed_interpolated_diff_1_shift_2',
 'fps_interpolated_transformed_diff_1_shift_2',
'ATVI_gaming_rr',
 'TTWO_gaming_rr',
 'AMD_rr',
 'SandP_rr',
 'NasdaqTech_rr',

]

y_more = ["return_ratio",
    'return_ratio_shift_1',
 'return_ratio_shift_2',
 'return_ratio_shift_3',
 'return_ratio_shift_4',
 'return_ratio_shift_5',
 'return_ratio_shift_6',
 'return_ratio_shift_7',
          'day_of_week',
 'day_of_year',
 'week',
 'quarter'
]

# %%
variables = train.columns.tolist()
variables.remove("y_return_ratio")
features = train[variables].columns
target = 'y_return_ratio'

# %%
len(features)
# Out:
# 60

# %% [markdown]
# # Korelacje Spearmana

# %%
corr_matrix = whole.drop(columns=['y_return_ratio']).corr("spearman").abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

var1 = [col for col in upper.columns if upper[col].max() < 0.9]
var2 = [col for col in upper.columns if upper[col].max() < 0.7]
var3 = [col for col in upper.columns if upper[col].max() < 0.5]
var4 = [col for col in upper.columns if upper[col].max() < 0.4]
var5 = [col for col in upper.columns if upper[col].max() < 0.3]

print(len(var1))
print(len(var2))
print(len(var3))
print(len(var4))
print(len(var5))
# Out:
# 41
# 36
# 28
# 24
# 17

# %%
upper
# Out:
#                                              return_ratio_shift_1  \
# return_ratio_shift_1                                          NaN
# return_ratio_shift_2                                          NaN
# return_ratio_shift_3                                          NaN
# return_ratio_shift_4                                          NaN
# return_ratio_shift_5                                          NaN
# return_ratio_shift_6                                          NaN
# return_ratio_shift_7                                          NaN
# TensorFlow__diff_1_shift_4                                    NaN
# deep learning__diff_1_shift_4                                 NaN
# Artificial Intelligence__diff_1_shift_19                      NaN
# Machine Learning__diff_1_shift_4                              NaN
# neural network__diff_1_shift_9                                NaN
# MXNet__diff_1_shift_9                                         NaN
# blockchain_news_diff_1_shift_4                                NaN
# GPU_news_diff_1_shift_17                                      NaN
# gaming_news_diff_1_shift_2                                    NaN
# SandP_diff_1                                                  NaN
# NasdaqTech_diff_1                                             NaN
# ATVI_gaming_diff_1                                            NaN
# TTWO_gaming_diff_1                                            NaN
# UBSFY_gaming_diff_1                                           NaN
# fps_transformed_ffill_diff_1_shift_2                          NaN
# fps_transformed_interpolated_diff_1_shift_2                   NaN
# fps_interpolated_transformed_diff_1_shift_2                   NaN
# PLUS_DM_diff_1                                                NaN
# MINUS_DM_diff_1_shift_8                                       NaN
# AD_diff_1                                                     NaN
# OBV_diff_1                                                    NaN
# MIDPOINT_diff_1                                               NaN
# MIDPRICE_diff_1                                               NaN
# SAR_diff_1_shift_13                                           NaN
# TEMA_diff_1                                                   NaN
# AVGPRICE_diff_1                                               NaN
# MEDPRICE_diff_1                                               NaN
# TYPPRICE_diff_1                                               NaN
# WCLPRICE_diff_1                                               NaN
# LINEARREG_diff_1                                              NaN
# TSF_diff_1                                                    NaN
# ADD_diff_1                                                    NaN
# MAX_diff_1                                                    NaN
# MAXINDEX_diff_1                                               NaN
# MIN_diff_1                                                    NaN
# MININDEX_diff_1_shift_19                                      NaN
# MULT_diff_1                                                   NaN
# ATAN_diff_1                                                   NaN
# CEIL_diff_1                                                   NaN
# FLOOR_diff_1                                                  NaN
# LN_diff_1                                                     NaN
# LOG10_diff_1                                                  NaN
# SQRT_diff_1                                                   NaN
# ATVI_gaming_rr                                                NaN
# TTWO_gaming_rr                                                NaN
# AMD_rr                                                        NaN
# SandP_rr                                                      NaN
# NasdaqTech_rr                                                 NaN
# day_of_week                                                   NaN
# day_of_year                                                   NaN
# week                                                          NaN
# quarter                                                       NaN
# return_ratio                                                  NaN
#
#                                              return_ratio_shift_2  \
# return_ratio_shift_1                                     0.044406
# return_ratio_shift_2                                          NaN
# return_ratio_shift_3                                          NaN
# return_ratio_shift_4                                          NaN
# return_ratio_shift_5                                          NaN
# return_ratio_shift_6                                          NaN
# return_ratio_shift_7                                          NaN
# TensorFlow__diff_1_shift_4                                    NaN
# deep learning__diff_1_shift_4                                 NaN
# Artificial Intelligence__diff_1_shift_19                      NaN
# Machine Learning__diff_1_shift_4                              NaN
# neural network__diff_1_shift_9                                NaN
# MXNet__diff_1_shift_9                                         NaN
# blockchain_news_diff_1_shift_4                                NaN
# GPU_news_diff_1_shift_17                                      NaN
# gaming_news_diff_1_shift_2                                    NaN
# SandP_diff_1                                                  NaN
# NasdaqTech_diff_1                                             NaN
# ATVI_gaming_diff_1                                            NaN
# TTWO_gaming_diff_1                                            NaN
# UBSFY_gaming_diff_1                                           NaN
# fps_transformed_ffill_diff_1_shift_2                          NaN
# fps_transformed_interpolated_diff_1_shift_2                   NaN
# fps_interpolated_transformed_diff_1_shift_2                   NaN
# PLUS_DM_diff_1                                                NaN
# MINUS_DM_diff_1_shift_8                                       NaN
# AD_diff_1                                                     NaN
# OBV_diff_1                                                    NaN
# MIDPOINT_diff_1                                               NaN
# MIDPRICE_diff_1                                               NaN
# SAR_diff_1_shift_13                                           NaN
# TEMA_diff_1                                                   NaN
# AVGPRICE_diff_1                                               NaN
# MEDPRICE_diff_1                                               NaN
# TYPPRICE_diff_1                                               NaN
# WCLPRICE_diff_1                                               NaN
# LINEARREG_diff_1                                              NaN
# TSF_diff_1                                                    NaN
# ADD_diff_1                                                    NaN
# MAX_diff_1                                                    NaN
# MAXINDEX_diff_1                                               NaN
# MIN_diff_1                                                    NaN
# MININDEX_diff_1_shift_19                                      NaN
# MULT_diff_1                                                   NaN
# ATAN_diff_1                                                   NaN
# CEIL_diff_1                                                   NaN
# FLOOR_diff_1                                                  NaN
# LN_diff_1                                                     NaN
# LOG10_diff_1                                                  NaN
# SQRT_diff_1                                                   NaN
# ATVI_gaming_rr                                                NaN
# TTWO_gaming_rr                                                NaN
# AMD_rr                                                        NaN
# SandP_rr                                                      NaN
# NasdaqTech_rr                                                 NaN
# day_of_week                                                   NaN
# day_of_year                                                   NaN
# week                                                          NaN
# quarter                                                       NaN
# return_ratio                                                  NaN
#
#                                              return_ratio_shift_3  \
# return_ratio_shift_1                                     0.058389
# return_ratio_shift_2                                     0.052678
# return_ratio_shift_3                                          NaN
# return_ratio_shift_4                                          NaN
# return_ratio_shift_5                                          NaN
# return_ratio_shift_6                                          NaN
# return_ratio_shift_7                                          NaN
# TensorFlow__diff_1_shift_4                                    NaN
# deep learning__diff_1_shift_4                                 NaN
# Artificial Intelligence__diff_1_shift_19                      NaN
# Machine Learning__diff_1_shift_4                              NaN
# neural network__diff_1_shift_9                                NaN
# MXNet__diff_1_shift_9                                         NaN
# blockchain_news_diff_1_shift_4                                NaN
# GPU_news_diff_1_shift_17                                      NaN
# gaming_news_diff_1_shift_2                                    NaN
# SandP_diff_1                                                  NaN
# NasdaqTech_diff_1                                             NaN
# ATVI_gaming_diff_1                                            NaN
# TTWO_gaming_diff_1                                            NaN
# UBSFY_gaming_diff_1                                           NaN
# fps_transformed_ffill_diff_1_shift_2                          NaN
# fps_transformed_interpolated_diff_1_shift_2                   NaN
# fps_interpolated_transformed_diff_1_shift_2                   NaN
# PLUS_DM_diff_1                                                NaN
# MINUS_DM_diff_1_shift_8                                       NaN
# AD_diff_1                                                     NaN
# OBV_diff_1                                                    NaN
# MIDPOINT_diff_1                                               NaN
# MIDPRICE_diff_1                                               NaN
# SAR_diff_1_shift_13                                           NaN
# TEMA_diff_1                                                   NaN
# AVGPRICE_diff_1                                               NaN
# MEDPRICE_diff_1                                               NaN
# TYPPRICE_diff_1                                               NaN
# WCLPRICE_diff_1                                               NaN
# LINEARREG_diff_1                                              NaN
# TSF_diff_1                                                    NaN
# ADD_diff_1                                                    NaN
# MAX_diff_1                                                    NaN
# MAXINDEX_diff_1                                               NaN
# MIN_diff_1                                                    NaN
# MININDEX_diff_1_shift_19                                      NaN
# MULT_diff_1                                                   NaN
# ATAN_diff_1                                                   NaN
# CEIL_diff_1                                                   NaN
# FLOOR_diff_1                                                  NaN
# LN_diff_1                                                     NaN
# LOG10_diff_1                                                  NaN
# SQRT_diff_1                                                   NaN
# ATVI_gaming_rr                                                NaN
# TTWO_gaming_rr                                                NaN
# AMD_rr                                                        NaN
# SandP_rr                                                      NaN
# NasdaqTech_rr                                                 NaN
# day_of_week                                                   NaN
# day_of_year                                                   NaN
# week                                                          NaN
# quarter                                                       NaN
# return_ratio                                                  NaN
#
#                                              return_ratio_shift_4  \
# return_ratio_shift_1                                     0.009579
# return_ratio_shift_2                                     0.056338
# return_ratio_shift_3                                     0.055930
# return_ratio_shift_4                                          NaN
# return_ratio_shift_5                                          NaN
# return_ratio_shift_6                                          NaN
# return_ratio_shift_7                                          NaN
# TensorFlow__diff_1_shift_4                                    NaN
# deep learning__diff_1_shift_4                                 NaN
# Artificial Intelligence__diff_1_shift_19                      NaN
# Machine Learning__diff_1_shift_4                              NaN
# neural network__diff_1_shift_9                                NaN
# MXNet__diff_1_shift_9                                         NaN
# blockchain_news_diff_1_shift_4                                NaN
# GPU_news_diff_1_shift_17                                      NaN
# gaming_news_diff_1_shift_2                                    NaN
# SandP_diff_1                                                  NaN
# NasdaqTech_diff_1                                             NaN
# ATVI_gaming_diff_1                                            NaN
# TTWO_gaming_diff_1                                            NaN
# UBSFY_gaming_diff_1                                           NaN
# fps_transformed_ffill_diff_1_shift_2                          NaN
# fps_transformed_interpolated_diff_1_shift_2                   NaN
# fps_interpolated_transformed_diff_1_shift_2                   NaN
# PLUS_DM_diff_1                                                NaN
# MINUS_DM_diff_1_shift_8                                       NaN
# AD_diff_1                                                     NaN
# OBV_diff_1                                                    NaN
# MIDPOINT_diff_1                                               NaN
# MIDPRICE_diff_1                                               NaN
# SAR_diff_1_shift_13                                           NaN
# TEMA_diff_1                                                   NaN
# AVGPRICE_diff_1                                               NaN
# MEDPRICE_diff_1                                               NaN
# TYPPRICE_diff_1                                               NaN
# WCLPRICE_diff_1                                               NaN
# LINEARREG_diff_1                                              NaN
# TSF_diff_1                                                    NaN
# ADD_diff_1                                                    NaN
# MAX_diff_1                                                    NaN
# MAXINDEX_diff_1                                               NaN
# MIN_diff_1                                                    NaN
# MININDEX_diff_1_shift_19                                      NaN
# MULT_diff_1                                                   NaN
# ATAN_diff_1                                                   NaN
# CEIL_diff_1                                                   NaN
# FLOOR_diff_1                                                  NaN
# LN_diff_1                                                     NaN
# LOG10_diff_1                                                  NaN
# SQRT_diff_1                                                   NaN
# ATVI_gaming_rr                                                NaN
# TTWO_gaming_rr                                                NaN
# AMD_rr                                                        NaN
# SandP_rr                                                      NaN
# NasdaqTech_rr                                                 NaN
# day_of_week                                                   NaN
# day_of_year                                                   NaN
# week                                                          NaN
# quarter                                                       NaN
# return_ratio                                                  NaN
#
#                                              return_ratio_shift_5  \
# return_ratio_shift_1                                     0.034933
# return_ratio_shift_2                                     0.010228
# return_ratio_shift_3                                     0.051897
# return_ratio_shift_4                                     0.033874
# return_ratio_shift_5                                          NaN
# return_ratio_shift_6                                          NaN
# return_ratio_shift_7                                          NaN
# TensorFlow__diff_1_shift_4                                    NaN
# deep learning__diff_1_shift_4                                 NaN
# Artificial Intelligence__diff_1_shift_19                      NaN
# Machine Learning__diff_1_shift_4                              NaN
# neural network__diff_1_shift_9                                NaN
# MXNet__diff_1_shift_9                                         NaN
# blockchain_news_diff_1_shift_4                                NaN
# GPU_news_diff_1_shift_17                                      NaN
# gaming_news_diff_1_shift_2                                    NaN
# SandP_diff_1                                                  NaN
# NasdaqTech_diff_1                                             NaN
# ATVI_gaming_diff_1                                            NaN
# TTWO_gaming_diff_1                                            NaN
# UBSFY_gaming_diff_1                                           NaN
# fps_transformed_ffill_diff_1_shift_2                          NaN
# fps_transformed_interpolated_diff_1_shift_2                   NaN
# fps_interpolated_transformed_diff_1_shift_2                   NaN
# PLUS_DM_diff_1                                                NaN
# MINUS_DM_diff_1_shift_8                                       NaN
# AD_diff_1                                                     NaN
# OBV_diff_1                                                    NaN
# MIDPOINT_diff_1                                               NaN
# MIDPRICE_diff_1                                               NaN
# SAR_diff_1_shift_13                                           NaN
# TEMA_diff_1                                                   NaN
# AVGPRICE_diff_1                                               NaN
# MEDPRICE_diff_1                                               NaN
# TYPPRICE_diff_1                                               NaN
# WCLPRICE_diff_1                                               NaN
# LINEARREG_diff_1                                              NaN
# TSF_diff_1                                                    NaN
# ADD_diff_1                                                    NaN
# MAX_diff_1                                                    NaN
# MAXINDEX_diff_1                                               NaN
# MIN_diff_1                                                    NaN
# MININDEX_diff_1_shift_19                                      NaN
# MULT_diff_1                                                   NaN
# ATAN_diff_1                                                   NaN
# CEIL_diff_1                                                   NaN
# FLOOR_diff_1                                                  NaN
# LN_diff_1                                                     NaN
# LOG10_diff_1                                                  NaN
# SQRT_diff_1                                                   NaN
# ATVI_gaming_rr                                                NaN
# TTWO_gaming_rr                                                NaN
# AMD_rr                                                        NaN
# SandP_rr                                                      NaN
# NasdaqTech_rr                                                 NaN
# day_of_week                                                   NaN
# day_of_year                                                   NaN
# week                                                          NaN
# quarter                                                       NaN
# return_ratio                                                  NaN
#
#                                              return_ratio_shift_6  \
# return_ratio_shift_1                                     0.001351
# return_ratio_shift_2                                     0.035062
# return_ratio_shift_3                                     0.002066
# return_ratio_shift_4                                     0.065288
# return_ratio_shift_5                                     0.044609
# return_ratio_shift_6                                          NaN
# return_ratio_shift_7                                          NaN
# TensorFlow__diff_1_shift_4                                    NaN
# deep learning__diff_1_shift_4                                 NaN
# Artificial Intelligence__diff_1_shift_19                      NaN
# Machine Learning__diff_1_shift_4                              NaN
# neural network__diff_1_shift_9                                NaN
# MXNet__diff_1_shift_9                                         NaN
# blockchain_news_diff_1_shift_4                                NaN
# GPU_news_diff_1_shift_17                                      NaN
# gaming_news_diff_1_shift_2                                    NaN
# SandP_diff_1                                                  NaN
# NasdaqTech_diff_1                                             NaN
# ATVI_gaming_diff_1                                            NaN
# TTWO_gaming_diff_1                                            NaN
# UBSFY_gaming_diff_1                                           NaN
# fps_transformed_ffill_diff_1_shift_2                          NaN
# fps_transformed_interpolated_diff_1_shift_2                   NaN
# fps_interpolated_transformed_diff_1_shift_2                   NaN
# PLUS_DM_diff_1                                                NaN
# MINUS_DM_diff_1_shift_8                                       NaN
# AD_diff_1                                                     NaN
# OBV_diff_1                                                    NaN
# MIDPOINT_diff_1                                               NaN
# MIDPRICE_diff_1                                               NaN
# SAR_diff_1_shift_13                                           NaN
# TEMA_diff_1                                                   NaN
# AVGPRICE_diff_1                                               NaN
# MEDPRICE_diff_1                                               NaN
# TYPPRICE_diff_1                                               NaN
# WCLPRICE_diff_1                                               NaN
# LINEARREG_diff_1                                              NaN
# TSF_diff_1                                                    NaN
# ADD_diff_1                                                    NaN
# MAX_diff_1                                                    NaN
# MAXINDEX_diff_1                                               NaN
# MIN_diff_1                                                    NaN
# MININDEX_diff_1_shift_19                                      NaN
# MULT_diff_1                                                   NaN
# ATAN_diff_1                                                   NaN
# CEIL_diff_1                                                   NaN
# FLOOR_diff_1                                                  NaN
# LN_diff_1                                                     NaN
# LOG10_diff_1                                                  NaN
# SQRT_diff_1                                                   NaN
# ATVI_gaming_rr                                                NaN
# TTWO_gaming_rr                                                NaN
# AMD_rr                                                        NaN
# SandP_rr                                                      NaN
# NasdaqTech_rr                                                 NaN
# day_of_week                                                   NaN
# day_of_year                                                   NaN
# week                                                          NaN
# quarter                                                       NaN
# return_ratio                                                  NaN
#
#                                              return_ratio_shift_7  \
# return_ratio_shift_1                                     0.031199
# return_ratio_shift_2                                     0.007014
# return_ratio_shift_3                                     0.037312
# return_ratio_shift_4                                     0.000327
# return_ratio_shift_5                                     0.062269
# return_ratio_shift_6                                     0.045969
# return_ratio_shift_7                                          NaN
# TensorFlow__diff_1_shift_4                                    NaN
# deep learning__diff_1_shift_4                                 NaN
# Artificial Intelligence__diff_1_shift_19                      NaN
# Machine Learning__diff_1_shift_4                              NaN
# neural network__diff_1_shift_9                                NaN
# MXNet__diff_1_shift_9                                         NaN
# blockchain_news_diff_1_shift_4                                NaN
# GPU_news_diff_1_shift_17                                      NaN
# gaming_news_diff_1_shift_2                                    NaN
# SandP_diff_1                                                  NaN
# NasdaqTech_diff_1                                             NaN
# ATVI_gaming_diff_1                                            NaN
# TTWO_gaming_diff_1                                            NaN
# UBSFY_gaming_diff_1                                           NaN
# fps_transformed_ffill_diff_1_shift_2                          NaN
# fps_transformed_interpolated_diff_1_shift_2                   NaN
# fps_interpolated_transformed_diff_1_shift_2                   NaN
# PLUS_DM_diff_1                                                NaN
# MINUS_DM_diff_1_shift_8                                       NaN
# AD_diff_1                                                     NaN
# OBV_diff_1                                                    NaN
# MIDPOINT_diff_1                                               NaN
# MIDPRICE_diff_1                                               NaN
# SAR_diff_1_shift_13                                           NaN
# TEMA_diff_1                                                   NaN
# AVGPRICE_diff_1                                               NaN
# MEDPRICE_diff_1                                               NaN
# TYPPRICE_diff_1                                               NaN
# WCLPRICE_diff_1                                               NaN
# LINEARREG_diff_1                                              NaN
# TSF_diff_1                                                    NaN
# ADD_diff_1                                                    NaN
# MAX_diff_1                                                    NaN
# MAXINDEX_diff_1                                               NaN
# MIN_diff_1                                                    NaN
# MININDEX_diff_1_shift_19                                      NaN
# MULT_diff_1                                                   NaN
# ATAN_diff_1                                                   NaN
# CEIL_diff_1                                                   NaN
# FLOOR_diff_1                                                  NaN
# LN_diff_1                                                     NaN
# LOG10_diff_1                                                  NaN
# SQRT_diff_1                                                   NaN
# ATVI_gaming_rr                                                NaN
# TTWO_gaming_rr                                                NaN
# AMD_rr                                                        NaN
# SandP_rr                                                      NaN
# NasdaqTech_rr                                                 NaN
# day_of_week                                                   NaN
# day_of_year                                                   NaN
# week                                                          NaN
# quarter                                                       NaN
# return_ratio                                                  NaN
#
#                                              TensorFlow__diff_1_shift_4  \
# return_ratio_shift_1                                           0.029259
# return_ratio_shift_2                                           0.037602
# return_ratio_shift_3                                           0.052262
# return_ratio_shift_4                                           0.055098
# return_ratio_shift_5                                           0.056393
# return_ratio_shift_6                                           0.030189
# return_ratio_shift_7                                           0.044346
# TensorFlow__diff_1_shift_4                                          NaN
# deep learning__diff_1_shift_4                                       NaN
# Artificial Intelligence__diff_1_shift_19                            NaN
# Machine Learning__diff_1_shift_4                                    NaN
# neural network__diff_1_shift_9                                      NaN
# MXNet__diff_1_shift_9                                               NaN
# blockchain_news_diff_1_shift_4                                      NaN
# GPU_news_diff_1_shift_17                                            NaN
# gaming_news_diff_1_shift_2                                          NaN
# SandP_diff_1                                                        NaN
# NasdaqTech_diff_1                                                   NaN
# ATVI_gaming_diff_1                                                  NaN
# TTWO_gaming_diff_1                                                  NaN
# UBSFY_gaming_diff_1                                                 NaN
# fps_transformed_ffill_diff_1_shift_2                                NaN
# fps_transformed_interpolated_diff_1_shift_2                         NaN
# fps_interpolated_transformed_diff_1_shift_2                         NaN
# PLUS_DM_diff_1                                                      NaN
# MINUS_DM_diff_1_shift_8                                             NaN
# AD_diff_1                                                           NaN
# OBV_diff_1                                                          NaN
# MIDPOINT_diff_1                                                     NaN
# MIDPRICE_diff_1                                                     NaN
# SAR_diff_1_shift_13                                                 NaN
# TEMA_diff_1                                                         NaN
# AVGPRICE_diff_1                                                     NaN
# MEDPRICE_diff_1                                                     NaN
# TYPPRICE_diff_1                                                     NaN
# WCLPRICE_diff_1                                                     NaN
# LINEARREG_diff_1                                                    NaN
# TSF_diff_1                                                          NaN
# ADD_diff_1                                                          NaN
# MAX_diff_1                                                          NaN
# MAXINDEX_diff_1                                                     NaN
# MIN_diff_1                                                          NaN
# MININDEX_diff_1_shift_19                                            NaN
# MULT_diff_1                                                         NaN
# ATAN_diff_1                                                         NaN
# CEIL_diff_1                                                         NaN
# FLOOR_diff_1                                                        NaN
# LN_diff_1                                                           NaN
# LOG10_diff_1                                                        NaN
# SQRT_diff_1                                                         NaN
# ATVI_gaming_rr                                                      NaN
# TTWO_gaming_rr                                                      NaN
# AMD_rr                                                              NaN
# SandP_rr                                                            NaN
# NasdaqTech_rr                                                       NaN
# day_of_week                                                         NaN
# day_of_year                                                         NaN
# week                                                                NaN
# quarter                                                             NaN
# return_ratio                                                        NaN
#
#                                              deep learning__diff_1_shift_4  \
# return_ratio_shift_1                                              0.020021
# return_ratio_shift_2                                              0.037641
# return_ratio_shift_3                                              0.055537
# return_ratio_shift_4                                              0.042039
# return_ratio_shift_5                                              0.045239
# return_ratio_shift_6                                              0.034477
# return_ratio_shift_7                                              0.037545
# TensorFlow__diff_1_shift_4                                        0.461204
# deep learning__diff_1_shift_4                                          NaN
# Artificial Intelligence__diff_1_shift_19                               NaN
# Machine Learning__diff_1_shift_4                                       NaN
# neural network__diff_1_shift_9                                         NaN
# MXNet__diff_1_shift_9                                                  NaN
# blockchain_news_diff_1_shift_4                                         NaN
# GPU_news_diff_1_shift_17                                               NaN
# gaming_news_diff_1_shift_2                                             NaN
# SandP_diff_1                                                           NaN
# NasdaqTech_diff_1                                                      NaN
# ATVI_gaming_diff_1                                                     NaN
# TTWO_gaming_diff_1                                                     NaN
# UBSFY_gaming_diff_1                                                    NaN
# fps_transformed_ffill_diff_1_shift_2                                   NaN
# fps_transformed_interpolated_diff_1_shift_2                            NaN
# fps_interpolated_transformed_diff_1_shift_2                            NaN
# PLUS_DM_diff_1                                                         NaN
# MINUS_DM_diff_1_shift_8                                                NaN
# AD_diff_1                                                              NaN
# OBV_diff_1                                                             NaN
# MIDPOINT_diff_1                                                        NaN
# MIDPRICE_diff_1                                                        NaN
# SAR_diff_1_shift_13                                                    NaN
# TEMA_diff_1                                                            NaN
# AVGPRICE_diff_1                                                        NaN
# MEDPRICE_diff_1                                                        NaN
# TYPPRICE_diff_1                                                        NaN
# WCLPRICE_diff_1                                                        NaN
# LINEARREG_diff_1                                                       NaN
# TSF_diff_1                                                             NaN
# ADD_diff_1                                                             NaN
# MAX_diff_1                                                             NaN
# MAXINDEX_diff_1                                                        NaN
# MIN_diff_1                                                             NaN
# MININDEX_diff_1_shift_19                                               NaN
# MULT_diff_1                                                            NaN
# ATAN_diff_1                                                            NaN
# CEIL_diff_1                                                            NaN
# FLOOR_diff_1                                                           NaN
# LN_diff_1                                                              NaN
# LOG10_diff_1                                                           NaN
# SQRT_diff_1                                                            NaN
# ATVI_gaming_rr                                                         NaN
# TTWO_gaming_rr                                                         NaN
# AMD_rr                                                                 NaN
# SandP_rr                                                               NaN
# NasdaqTech_rr                                                          NaN
# day_of_week                                                            NaN
# day_of_year                                                            NaN
# week                                                                   NaN
# quarter                                                                NaN
# return_ratio                                                           NaN
#
#                                              Artificial Intelligence__diff_1_shift_19  \
# return_ratio_shift_1                                                         0.034034
# return_ratio_shift_2                                                         0.030760
# return_ratio_shift_3                                                         0.004710
# return_ratio_shift_4                                                         0.005968
# return_ratio_shift_5                                                         0.009807
# return_ratio_shift_6                                                         0.000832
# return_ratio_shift_7                                                         0.006946
# TensorFlow__diff_1_shift_4                                                   0.214061
# deep learning__diff_1_shift_4                                                0.357250
# Artificial Intelligence__diff_1_shift_19                                          NaN
# Machine Learning__diff_1_shift_4                                                  NaN
# neural network__diff_1_shift_9                                                    NaN
# MXNet__diff_1_shift_9                                                             NaN
# blockchain_news_diff_1_shift_4                                                    NaN
# GPU_news_diff_1_shift_17                                                          NaN
# gaming_news_diff_1_shift_2                                                        NaN
# SandP_diff_1                                                                      NaN
# NasdaqTech_diff_1                                                                 NaN
# ATVI_gaming_diff_1                                                                NaN
# TTWO_gaming_diff_1                                                                NaN
# UBSFY_gaming_diff_1                                                               NaN
# fps_transformed_ffill_diff_1_shift_2                                              NaN
# fps_transformed_interpolated_diff_1_shift_2                                       NaN
# fps_interpolated_transformed_diff_1_shift_2                                       NaN
# PLUS_DM_diff_1                                                                    NaN
# MINUS_DM_diff_1_shift_8                                                           NaN
# AD_diff_1                                                                         NaN
# OBV_diff_1                                                                        NaN
# MIDPOINT_diff_1                                                                   NaN
# MIDPRICE_diff_1                                                                   NaN
# SAR_diff_1_shift_13                                                               NaN
# TEMA_diff_1                                                                       NaN
# AVGPRICE_diff_1                                                                   NaN
# MEDPRICE_diff_1                                                                   NaN
# TYPPRICE_diff_1                                                                   NaN
# WCLPRICE_diff_1                                                                   NaN
# LINEARREG_diff_1                                                                  NaN
# TSF_diff_1                                                                        NaN
# ADD_diff_1                                                                        NaN
# MAX_diff_1                                                                        NaN
# MAXINDEX_diff_1                                                                   NaN
# MIN_diff_1                                                                        NaN
# MININDEX_diff_1_shift_19                                                          NaN
# MULT_diff_1                                                                       NaN
# ATAN_diff_1                                                                       NaN
# CEIL_diff_1                                                                       NaN
# FLOOR_diff_1                                                                      NaN
# LN_diff_1                                                                         NaN
# LOG10_diff_1                                                                      NaN
# SQRT_diff_1                                                                       NaN
# ATVI_gaming_rr                                                                    NaN
# TTWO_gaming_rr                                                                    NaN
# AMD_rr                                                                            NaN
# SandP_rr                                                                          NaN
# NasdaqTech_rr                                                                     NaN
# day_of_week                                                                       NaN
# day_of_year                                                                       NaN
# week                                                                              NaN
# quarter                                                                           NaN
# return_ratio                                                                      NaN
#
#                                              ...  ATVI_gaming_rr  \
# return_ratio_shift_1                         ...        0.181098
# return_ratio_shift_2                         ...        0.023896
# return_ratio_shift_3                         ...        0.006674
# return_ratio_shift_4                         ...        0.020835
# return_ratio_shift_5                         ...        0.040991
# return_ratio_shift_6                         ...        0.004194
# return_ratio_shift_7                         ...        0.015125
# TensorFlow__diff_1_shift_4                   ...        0.002237
# deep learning__diff_1_shift_4                ...        0.002260
# Artificial Intelligence__diff_1_shift_19     ...        0.006332
# Machine Learning__diff_1_shift_4             ...        0.015714
# neural network__diff_1_shift_9               ...        0.042464
# MXNet__diff_1_shift_9                        ...        0.010855
# blockchain_news_diff_1_shift_4               ...        0.031282
# GPU_news_diff_1_shift_17                     ...        0.008571
# gaming_news_diff_1_shift_2                   ...        0.002721
# SandP_diff_1                                 ...        0.495808
# NasdaqTech_diff_1                            ...        0.527643
# ATVI_gaming_diff_1                           ...        0.963540
# TTWO_gaming_diff_1                           ...        0.589936
# UBSFY_gaming_diff_1                          ...        0.280808
# fps_transformed_ffill_diff_1_shift_2         ...        0.059988
# fps_transformed_interpolated_diff_1_shift_2  ...        0.036823
# fps_interpolated_transformed_diff_1_shift_2  ...        0.037410
# PLUS_DM_diff_1                               ...        0.268128
# MINUS_DM_diff_1_shift_8                      ...        0.024977
# AD_diff_1                                    ...        0.210476
# OBV_diff_1                                   ...        0.223542
# MIDPOINT_diff_1                              ...        0.154522
# MIDPRICE_diff_1                              ...        0.151113
# SAR_diff_1_shift_13                          ...        0.013306
# TEMA_diff_1                                  ...        0.168832
# AVGPRICE_diff_1                              ...        0.368700
# MEDPRICE_diff_1                              ...        0.363563
# TYPPRICE_diff_1                              ...        0.348078
# WCLPRICE_diff_1                              ...        0.336890
# LINEARREG_diff_1                             ...        0.148635
# TSF_diff_1                                   ...        0.146746
# ADD_diff_1                                   ...        0.363563
# MAX_diff_1                                   ...        0.120497
# MAXINDEX_diff_1                              ...        0.068394
# MIN_diff_1                                   ...        0.106537
# MININDEX_diff_1_shift_19                     ...        0.021049
# MULT_diff_1                                  ...        0.349116
# ATAN_diff_1                                  ...        0.276582
# CEIL_diff_1                                  ...        0.219715
# FLOOR_diff_1                                 ...        0.220945
# LN_diff_1                                    ...        0.307071
# LOG10_diff_1                                 ...        0.307071
# SQRT_diff_1                                  ...        0.285838
# ATVI_gaming_rr                               ...             NaN
# TTWO_gaming_rr                               ...             NaN
# AMD_rr                                       ...             NaN
# SandP_rr                                     ...             NaN
# ...
# SAR_diff_1_shift_13                                0.019353  0.016639
# TEMA_diff_1                                        0.142265  0.309545
# AVGPRICE_diff_1                                    0.343069  0.505621
# MEDPRICE_diff_1                                    0.339617  0.482566
# TYPPRICE_diff_1                                    0.320037  0.467761
# WCLPRICE_diff_1                                    0.308467  0.446148
# LINEARREG_diff_1                                   0.133789  0.265069
# TSF_diff_1                                         0.131502  0.263490
# ADD_diff_1                                         0.339623  0.482583
# MAX_diff_1                                         0.094360  0.195901
# MAXINDEX_diff_1                                    0.066172  0.170536
# MIN_diff_1                                         0.078018  0.117529
# MININDEX_diff_1_shift_19                           0.001859  0.018229
# MULT_diff_1                                        0.331814  0.462593
# ATAN_diff_1                                        0.231912  0.329328
# CEIL_diff_1                                        0.208781  0.296783
# FLOOR_diff_1                                       0.209274  0.297283
# LN_diff_1                                          0.264781  0.365557
# LOG10_diff_1                                       0.264781  0.365557
# SQRT_diff_1                                        0.250343  0.352864
# ATVI_gaming_rr                                     0.589017  0.321503
# TTWO_gaming_rr                                          NaN  0.306054
# AMD_rr                                                  NaN       NaN
# SandP_rr                                                NaN       NaN
# NasdaqTech_rr                                           NaN       NaN
# day_of_week                                             NaN       NaN
# day_of_year                                             NaN       NaN
# week                                                    NaN       NaN
# quarter                                                 NaN       NaN
# return_ratio                                            NaN       NaN
#
#                                              SandP_rr  NasdaqTech_rr  \
# return_ratio_shift_1                         0.305774       0.302723
# return_ratio_shift_2                         0.012631       0.000904
# return_ratio_shift_3                         0.041941       0.000804
# return_ratio_shift_4                         0.003089       0.010422
# return_ratio_shift_5                         0.020537       0.019945
# return_ratio_shift_6                         0.026523       0.024094
# return_ratio_shift_7                         0.009052       0.010883
# TensorFlow__diff_1_shift_4                   0.006899       0.061211
# deep learning__diff_1_shift_4                0.006707       0.038159
# Artificial Intelligence__diff_1_shift_19     0.002475       0.017060
# Machine Learning__diff_1_shift_4             0.008615       0.038711
# neural network__diff_1_shift_9               0.024612       0.014713
# MXNet__diff_1_shift_9                        0.005145       0.022747
# blockchain_news_diff_1_shift_4               0.026097       0.065793
# GPU_news_diff_1_shift_17                     0.027282       0.055012
# gaming_news_diff_1_shift_2                   0.010914       0.064639
# SandP_diff_1                                 0.994510       0.775194
# NasdaqTech_diff_1                            0.757642       0.983124
# ATVI_gaming_diff_1                           0.468467       0.518050
# TTWO_gaming_diff_1                           0.452611       0.497299
# UBSFY_gaming_diff_1                          0.308952       0.309351
# fps_transformed_ffill_diff_1_shift_2         0.008808       0.001658
# fps_transformed_interpolated_diff_1_shift_2  0.030080       0.027397
# fps_interpolated_transformed_diff_1_shift_2  0.032926       0.028709
# PLUS_DM_diff_1                               0.319617       0.450236
# MINUS_DM_diff_1_shift_8                      0.052810       0.046065
# AD_diff_1                                    0.262865       0.301384
# OBV_diff_1                                   0.248179       0.372534
# MIDPOINT_diff_1                              0.194380       0.229532
# MIDPRICE_diff_1                              0.153047       0.205541
# SAR_diff_1_shift_13                          0.014240       0.021721
# TEMA_diff_1                                  0.252684       0.312923
# AVGPRICE_diff_1                              0.453714       0.628658
# MEDPRICE_diff_1                              0.434759       0.603001
# TYPPRICE_diff_1                              0.433182       0.599490
# WCLPRICE_diff_1                              0.406306       0.572047
# LINEARREG_diff_1                             0.238363       0.296838
# TSF_diff_1                                   0.236743       0.295243
# ADD_diff_1                                   0.434771       0.603014
# MAX_diff_1                                   0.135469       0.197929
# MAXINDEX_diff_1                              0.113315       0.182887
# MIN_diff_1                                   0.077355       0.095628
# MININDEX_diff_1_shift_19                     0.015086       0.003825
# MULT_diff_1                                  0.418606       0.578191
# ATAN_diff_1                                  0.346980       0.466291
# CEIL_diff_1                                  0.256575       0.381728
# FLOOR_diff_1                                 0.254695       0.378556
# LN_diff_1                                    0.364851       0.502319
# LOG10_diff_1                                 0.364851       0.502319
# SQRT_diff_1                                  0.337109       0.475406
# ATVI_gaming_rr                               0.498201       0.535819
# TTWO_gaming_rr                               0.475086       0.513919
# AMD_rr                                       0.432872       0.534258
# SandP_rr                                          NaN       0.777935
# NasdaqTech_rr                                     NaN            NaN
# day_of_week                                       NaN            NaN
# day_of_year                                       NaN            NaN
# week                                              NaN            NaN
# quarter                                           NaN            NaN
# return_ratio                                      NaN            NaN
#
#                                              day_of_week  day_of_year  \
# return_ratio_shift_1                            0.019019     0.019019
# return_ratio_shift_2                            0.015335     0.015335
# return_ratio_shift_3                            0.044643     0.044643
# return_ratio_shift_4                            0.013927     0.013927
# return_ratio_shift_5                            0.018997     0.018997
# return_ratio_shift_6                            0.017096     0.017096
# return_ratio_shift_7                            0.011811     0.011811
# TensorFlow__diff_1_shift_4                      0.040074     0.040074
# deep learning__diff_1_shift_4                   0.092109     0.092109
# Artificial Intelligence__diff_1_shift_19        0.020290     0.020290
# Machine Learning__diff_1_shift_4                0.078734     0.078734
# neural network__diff_1_shift_9                  0.057381     0.057381
# MXNet__diff_1_shift_9                           0.017868     0.017868
# blockchain_news_diff_1_shift_4                  0.044884     0.044884
# GPU_news_diff_1_shift_17                        0.000920     0.000920
# gaming_news_diff_1_shift_2                      0.019291     0.019291
# SandP_diff_1                                    0.023678     0.023678
# NasdaqTech_diff_1                               0.002329     0.002329
# ATVI_gaming_diff_1                              0.040371     0.040371
# TTWO_gaming_diff_1                              0.014608     0.014608
# UBSFY_gaming_diff_1                             0.002424     0.002424
# fps_transformed_ffill_diff_1_shift_2            0.026981     0.026981
# fps_transformed_interpolated_diff_1_shift_2     0.017379     0.017379
# fps_interpolated_transformed_diff_1_shift_2     0.017127     0.017127
# PLUS_DM_diff_1                                  0.001546     0.001546
# MINUS_DM_diff_1_shift_8                         0.024715     0.024715
# AD_diff_1                                       0.010650     0.010650
# OBV_diff_1                                      0.030803     0.030803
# MIDPOINT_diff_1                                 0.010584     0.010584
# MIDPRICE_diff_1                                 0.017428     0.017428
# SAR_diff_1_shift_13                             0.011423     0.011423
# TEMA_diff_1                                     0.018747     0.018747
# AVGPRICE_diff_1                                 0.000895     0.000895
# MEDPRICE_diff_1                                 0.000360     0.000360
# TYPPRICE_diff_1                                 0.017568     0.017568
# WCLPRICE_diff_1                                 0.020169     0.020169
# LINEARREG_diff_1                                0.026215     0.026215
# TSF_diff_1                                      0.025767     0.025767
# ADD_diff_1                                      0.000348     0.000348
# MAX_diff_1                                      0.026197     0.026197
# MAXINDEX_diff_1                                 0.014278     0.014278
# MIN_diff_1                                      0.024727     0.024727
# MININDEX_diff_1_shift_19                        0.011126     0.011126
# MULT_diff_1                                     0.003218     0.003218
# ATAN_diff_1                                     0.025233     0.025233
# CEIL_diff_1                                     0.009258     0.009258
# FLOOR_diff_1                                    0.008286     0.008286
# LN_diff_1                                       0.010339     0.010339
# LOG10_diff_1                                    0.010339     0.010339
# SQRT_diff_1                                     0.009379     0.009379
# ATVI_gaming_rr                                  0.030334     0.030334
# TTWO_gaming_rr                                  0.029663     0.029663
# AMD_rr                                          0.004200     0.004200
# SandP_rr                                        0.024792     0.024792
# NasdaqTech_rr                                   0.004252     0.004252
# day_of_week                                          NaN     1.000000
# day_of_year                                          NaN          NaN
# week                                                 NaN          NaN
# quarter                                              NaN          NaN
# return_ratio                                         NaN          NaN
#
#                                                  week   quarter  return_ratio
# return_ratio_shift_1                         0.014249  0.016326      0.048918
# return_ratio_shift_2                         0.010565  0.010702      0.061675
# return_ratio_shift_3                         0.021066  0.019920      0.006129
# return_ratio_shift_4                         0.008628  0.014526      0.027389
# return_ratio_shift_5                         0.017260  0.024290      0.015487
# return_ratio_shift_6                         0.021961  0.034491      0.022383
# return_ratio_shift_7                         0.040554  0.046932      0.002468
# TensorFlow__diff_1_shift_4                   0.164969  0.140278      0.052395
# deep learning__diff_1_shift_4                0.109175  0.099786      0.033464
# Artificial Intelligence__diff_1_shift_19     0.098008  0.129538      0.026130
# Machine Learning__diff_1_shift_4             0.096396  0.105784      0.054982
# neural network__diff_1_shift_9               0.064083  0.056688      0.032372
# MXNet__diff_1_shift_9                        0.041060  0.039908      0.044027
# blockchain_news_diff_1_shift_4               0.046632  0.061470      0.055254
# GPU_news_diff_1_shift_17                     0.256582  0.241329      0.050355
# gaming_news_diff_1_shift_2                   0.072493  0.097410      0.060845
# SandP_diff_1                                 0.012470  0.000410      0.357819
# NasdaqTech_diff_1                            0.011589  0.008822      0.489679
# ATVI_gaming_diff_1                           0.044731  0.046743      0.300375
# TTWO_gaming_diff_1                           0.016117  0.008089      0.280892
# UBSFY_gaming_diff_1                          0.022471  0.018973      0.152299
# fps_transformed_ffill_diff_1_shift_2         0.031410  0.023183      0.005096
# fps_transformed_interpolated_diff_1_shift_2  0.039671  0.040046      0.018311
# fps_interpolated_transformed_diff_1_shift_2  0.039142  0.038535      0.017235
# PLUS_DM_diff_1                               0.007098  0.009506      0.517161
# MINUS_DM_diff_1_shift_8                      0.012117  0.008287      0.079959
# AD_diff_1                                    0.020994  0.019716      0.739639
# OBV_diff_1                                   0.010335  0.003900      0.858550
# MIDPOINT_diff_1                              0.032785  0.041882      0.358215
# MIDPRICE_diff_1                              0.020095  0.034905      0.228841
# SAR_diff_1_shift_13                          0.011786  0.011457      0.023353
# TEMA_diff_1                                  0.007254  0.018408      0.394611
# AVGPRICE_diff_1                              0.015086  0.010375      0.625527
# MEDPRICE_diff_1                              0.015193  0.008829      0.590072
# TYPPRICE_diff_1                              0.015412  0.007716      0.763176
# WCLPRICE_diff_1                              0.017125  0.010174      0.838240
# LINEARREG_diff_1                             0.013884  0.014238      0.373198
# TSF_diff_1                                   0.014421  0.016107      0.375955
# ADD_diff_1                                   0.015185  0.008822      0.590074
# MAX_diff_1                                   0.020818  0.031764      0.344637
# MAXINDEX_diff_1                              0.055470  0.056404      0.352661
# MIN_diff_1                                   0.026724  0.001072      0.114124
# MININDEX_diff_1_shift_19                     0.077055  0.089149      0.027659
# MULT_diff_1                                  0.014331  0.008710      0.560485
# ATAN_diff_1                                  0.023593  0.021075      0.899122
# CEIL_diff_1                                  0.001122  0.004852      0.766750
# FLOOR_diff_1                                 0.001978  0.006057      0.766649
# LN_diff_1                                    0.020879  0.016367      0.989692
# LOG10_diff_1                                 0.020879  0.016367      0.989692
# SQRT_diff_1                                  0.013773  0.009551      0.963650
# ATVI_gaming_rr                               0.050091  0.051788      0.305871
# TTWO_gaming_rr                               0.015308  0.009982      0.266837
# AMD_rr                                       0.010395  0.020158      0.359701
# SandP_rr                                     0.015375  0.003029      0.360179
# NasdaqTech_rr                                0.010490  0.009390      0.496553
# day_of_week                                  0.007639  0.003052      0.007617
# day_of_year                                  0.007639  0.003052      0.007617
# week                                              NaN  0.949144      0.026825
# quarter                                           NaN       NaN      0.021272
# return_ratio                                      NaN       NaN           NaN
#
# [60 rows x 60 columns]

# %%
# correlations = upper.iloc[0].sort_values(ascending=False)
# correlations

# %% [markdown]
# # ExtraTreesRegression

# %%
X_train1 = train1[var1]
y_train1 = train1[target]
X_test1 = val[var1]
y_test1 = val[target]

model = ExtraTreesRegressor()
model.fit(X_train1, y_train1)
feature_importances = pd.DataFrame(model.feature_importances_, index=X_train1.columns, columns=['importance']).sort_values('importance', ascending=False)
feature_importances
# Out:
# /home/michal/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
#                                              importance
# SandP_diff_1                                   0.058846
# return_ratio_shift_7                           0.053694
# day_of_week                                    0.038678
# return_ratio_shift_2                           0.036682
# UBSFY_gaming_diff_1                            0.035509
# return_ratio_shift_3                           0.034355
# ATVI_gaming_diff_1                             0.032175
# fps_transformed_interpolated_diff_1_shift_2    0.031984
# fps_transformed_ffill_diff_1_shift_2           0.030544
# neural network__diff_1_shift_9                 0.029630
# return_ratio_shift_5                           0.028928
# ATAN_diff_1                                    0.027808
# MXNet__diff_1_shift_9                          0.026520
# LINEARREG_diff_1                               0.025866
# PLUS_DM_diff_1                                 0.025499
# OBV_diff_1                                     0.025293
# AVGPRICE_diff_1                                0.024217
# AD_diff_1                                      0.023524
# gaming_news_diff_1_shift_2                     0.023168
# TEMA_diff_1                                    0.022587
# return_ratio_shift_4                           0.022492
# return_ratio_shift_6                           0.022487
# TTWO_gaming_diff_1                             0.022476
# SAR_diff_1_shift_13                            0.022045
# MIN_diff_1                                     0.020832
# MINUS_DM_diff_1_shift_8                        0.020787
# deep learning__diff_1_shift_4                  0.019442
# AMD_rr                                         0.018729
# Machine Learning__diff_1_shift_4               0.018225
# week                                           0.018137
# MIDPRICE_diff_1                                0.018025
# CEIL_diff_1                                    0.017684
# NasdaqTech_diff_1                              0.016551
# MININDEX_diff_1_shift_19                       0.015607
# Artificial Intelligence__diff_1_shift_19       0.014358
# MAX_diff_1                                     0.013745
# TensorFlow__diff_1_shift_4                     0.013734
# GPU_news_diff_1_shift_17                       0.013480
# blockchain_news_diff_1_shift_4                 0.012486
# MIDPOINT_diff_1                                0.012400
# MAXINDEX_diff_1                                0.010771

# %%
feature_importances.index[:i*10]
# Out:
# Index(['SandP_diff_1', 'neural network__diff_1_shift_9', 'AD_diff_1',
#        'ATVI_gaming_diff_1', 'OBV_diff_1', 'return_ratio_shift_3',
#        'return_ratio_shift_7', 'UBSFY_gaming_diff_1', 'return_ratio_shift_4',
#        'TEMA_diff_1', 'gaming_news_diff_1_shift_2', 'SAR_diff_1_shift_13',
#        'MXNet__diff_1_shift_9', 'Machine Learning__diff_1_shift_4',
#        'return_ratio_shift_2', 'day_of_week', 'AMD_rr', 'return_ratio_shift_5',
#        'week', 'TTWO_gaming_diff_1'],
#       dtype='object')

# %%
# scalerX = MinMaxScaler(feature_range=(0, 1))
# scalerY = MinMaxScaler(feature_range=(0, 1))
# for i in range(1, int(len(var1)/10)):
#     features_set = scalerX.fit_transform(train1[feature_importances.index[:i*10]])
#     features_set = np.reshape(features_set, (features_set.shape[0], features_set.shape[1], 1))    
#     labels = scalerY.fit_transform(pd.DataFrame(y_train1))
    
#     model = Sequential()
    
#     model.add(LSTM(units=50, return_sequences=True, input_shape=(features_set.shape[1], 1)))
#     model.add(Dropout(0.2))
    
#     model.add(LSTM(units=50, return_sequences=True))  
#     model.add(Dropout(0.2))

#     model.add(LSTM(units=50, return_sequences=True))  
#     model.add(Dropout(0.2))

#     model.add(LSTM(units=50))  
#     model.add(Dropout(0.2))
    
#     model.add(Dense(units = 1))
    
#     model.compile(optimizer = 'adam', loss = 'mean_squared_error')
#     model.fit(features_set, labels, epochs = 100, batch_size = 32)
    
#     test_features_set = scalerX.transform(val[feature_importances.index[:i*10]])
#     test_features_set = np.reshape(test_features_set, (test_features_set.shape[0], test_features_set.shape[1], 1))
    
#     predictions = model.predict(test_features_set)
#     predictions = scalerY.inverse_transform(predictions)
    
#     plt.figure(figsize=(10,6))
#     pd.Series([x[0] for x in predictions], index=y_test1.index).plot(label='pred')
#     y_test1.plot(label="real")
#     plt.legend()
#     plt.show()
# #     plt.plot(predictions)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-95-d68cb8fd11d4> in <module>
#      23
#      24     model.compile(optimizer = 'adam', loss = 'mean_squared_error')
# ---> 25     model.fit(features_set, labels, epochs = 100, batch_size = 32)
#      26
#      27     test_features_set = scalerX.transform(val[feature_importances.index[:i*10]])
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2695
#    2696     def __call__(self, inputs):
# -> 2697         if hasattr(get_session(), '_make_callable_from_options'):
#    2698             if py_any(is_sparse(x) for x in self.inputs):
#    2699                 if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in get_session()
#     197                 # not already marked as initialized.
#     198                 is_initialized = session.run(
# --> 199                     [tf.is_variable_initialized(v) for v in candidate_vars])
#     200                 uninitialized_vars = []
#     201                 for flag, v in zip(is_initialized, candidate_vars):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1315     def _run_fn(feed_dict, fetch_list, target_list, options, run_metadata):
#    1316       # Ensure any changes to the graph are reflected in the runtime.
# -> 1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
#    1319           options, feed_dict, fetch_list, target_list, run_metadata)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _extend_graph(self)
#    1350   def _extend_graph(self):
#    1351     with self._graph._session_run_lock():  # pylint: disable=protected-access
# -> 1352       tf_session.ExtendSession(self._session)
#    1353
#    1354   # The threshold to run garbage collection to delete dead tensors.
#
# KeyboardInterrupt:

# %%
scalerX = MinMaxScaler(feature_range=(0, 1))
scalerY = MinMaxScaler(feature_range=(0, 1))

# %%
trainX = train1[var5]
trainY = train1[target]

testX = val[var5]
testY = val[target]

labels = np.array(pd.DataFrame(y_train1))
labels = scalerY.fit_transform(labels)

features_set = np.array(scalerX.fit_transform(X_train1))
# features_set = np.array(X_train1)
features_set = np.reshape(features_set, (features_set.shape[0], features_set.shape[1], 1))

test_features_set = np.array(scalerX.transform(X_test1))
# test_features_set = np.array(X_test1)
test_features_set = np.reshape(test_features_set, (test_features_set.shape[0], test_features_set.shape[1], 1))
# Out:
# /home/michal/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
# i=5
# features_set = scalerX.fit_transform(train1[feature_importances.index[:i*10]])
# features_set = np.reshape(features_set, (features_set.shape[0], features_set.shape[1], 1))    
# labels = scalerY.fit_transform(pd.DataFrame(y_train1))

model = Sequential()

model.add(LSTM(units=50, return_sequences=True, input_shape=(features_set.shape[1], 1)))
model.add(Dropout(0.2))

model.add(LSTM(units=50, return_sequences=True))  
model.add(Dropout(0.2))

model.add(LSTM(units=50, return_sequences=True))  
model.add(Dropout(0.2))

model.add(LSTM(units=50))  
model.add(Dropout(0.2))

model.add(Dense(units = 1))

model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(features_set, labels, epochs = 50, batch_size = 32)

# test_features_set = scalerX.transform(val[feature_importances.index[:i*10]])
# test_features_set = np.reshape(test_features_set, (test_features_set.shape[0], test_features_set.shape[1], 1))
# Out:
# Epoch 1/50
# 1435/1435 [==============================] - 15s 10ms/step - loss: 0.0089
# Epoch 2/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0037
# Epoch 3/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0038
# Epoch 4/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0037
# Epoch 5/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0035
# Epoch 6/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0038
# Epoch 7/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0036
# Epoch 8/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0035
# Epoch 9/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0036
# Epoch 10/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0034
# Epoch 11/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0035
# Epoch 12/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0035
# Epoch 13/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0034
# Epoch 14/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0035
# Epoch 15/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0034
# Epoch 16/50
# 1435/1435 [==============================] - 2s 2ms/step - loss: 0.0035
# Epoch 17/50
# 1435/1435 [==============================] - 2s 2ms/step - loss: 0.0034
# Epoch 18/50
# 1435/1435 [==============================] - 2s 2ms/step - loss: 0.0034
# Epoch 19/50
# 1435/1435 [==============================] - 2s 2ms/step - loss: 0.0034
# Epoch 20/50
# 1435/1435 [==============================] - 2s 2ms/step - loss: 0.0034
# Epoch 21/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0034
# Epoch 22/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0033
# Epoch 23/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0032
# Epoch 24/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0034
# Epoch 25/50
# 1435/1435 [==============================] - 2s 2ms/step - loss: 0.0033
# Epoch 26/50
# 1435/1435 [==============================] - 2s 2ms/step - loss: 0.0033
# Epoch 27/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0033
# Epoch 28/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0034
# Epoch 29/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0033
# Epoch 30/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0033
# Epoch 31/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0033
# Epoch 32/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0033
# Epoch 33/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0034
# Epoch 34/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0033
# Epoch 35/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0033
# Epoch 36/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0032
# Epoch 37/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0033
# Epoch 38/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0033
# Epoch 39/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0033
# Epoch 40/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0033
# Epoch 41/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0032
# Epoch 42/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0032
# Epoch 43/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0033
# Epoch 44/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0032
# Epoch 45/50
# 1435/1435 [==============================] - 5s 3ms/step - loss: 0.0033
# Epoch 46/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0032
# Epoch 47/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0032
# Epoch 48/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0032
# Epoch 49/50
# 1435/1435 [==============================] - 2s 2ms/step - loss: 0.0032
# Epoch 50/50
# 1435/1435 [==============================] - 3s 2ms/step - loss: 0.0032

# %%
predictions = model.predict(test_features_set)
previous = predictions
predictions = scalerY.inverse_transform(predictions)

plt.figure(figsize=(10,6))
# pd.Series([x[0] for x in previous], index=y_test1.index).plot(label='pred')
print(previous)
print(predictions)
y_test1.plot(label="real")
plt.legend()
plt.show()
# Out:
# [[-19855.02  ]
#  [  2676.1582]
#  [  7130.7   ]
#  [-59412.28  ]
#  [  4725.8184]
#  [  7061.6543]
#  [-43672.137 ]
#  [  4343.7197]
#  [-15843.579 ]
#  [-24035.95  ]
#  [-24035.95  ]
#  [-52285.887 ]
#  [  4080.414 ]
#  [-27267.527 ]
#  [  4933.741 ]
#  [  4091.5293]
#  [  3792.2212]
#  [-43229.477 ]
#  [-44060.42  ]
#  [  4361.4453]
#  [  3600.5425]
#  [-36594.977 ]
#  [-19327.48  ]
#  [-38421.574 ]
#  [-53727.86  ]
#  [-86637.47  ]
#  [  9439.33  ]
#  [-71705.34  ]
#  [-81140.875 ]
#  [ 13900.347 ]
#  [-81026.34  ]
#  [  5003.8335]
#  [  5757.0215]
#  [  5719.124 ]
#  [-45701.098 ]
#  [-45701.098 ]
#  [  5107.9746]
#  [-63448.3   ]
#  [  4990.202 ]
#  [  3503.85  ]
#  [  3396.082 ]
#  [-33550.586 ]
#  [-33593.566 ]
#  [-76738.94  ]
#  [  6806.6807]
#  [-38666.33  ]
#  [  4991.3955]
#  [-51328.098 ]
#  [-28243.85  ]
#  [  3979.77  ]
#  [  4150.5225]
#  [-38890.598 ]
#  [  3897.1665]
#  [ -1431.8693]
#  [  3274.6943]
#  [-53199.66  ]
#  [  4372.194 ]
#  [-32400.709 ]
#  [-34606.508 ]
#  [-52609.234 ]
#  [  5178.507 ]
#  [-88254.43  ]
#  [-70795.516 ]
#  [  7479.771 ]
#  [  7479.771 ]
#  [-57969.03  ]
#  [  2494.5312]
#  [  5952.055 ]
#  [-51856.21  ]
#  [-43134.47  ]
#  [-77424.19  ]
#  [  6020.9307]
#  [-34309.727 ]
#  [  4596.463 ]
#  [-37051.09  ]
#  [-29331.387 ]
#  [  3485.4707]
#  [-24573.969 ]
#  [-35349.984 ]
#  [-28556.11  ]
#  [-27720.887 ]
#  [-30595.566 ]
#  [-36597.797 ]
#  [  2874.435 ]
#  [-13521.935 ]
#  [-21418.418 ]
#  [  1898.1616]
#  [-19916.447 ]
#  [  3460.768 ]
#  [  2983.5112]
#  [  5649.7217]
#  [  3809.376 ]
#  [  4441.732 ]
#  [  7720.797 ]
#  [-92009.65  ]
#  [-52483.957 ]
#  [-72170.18  ]
#  [  4268.519 ]
#  [  5071.9375]
#  [-34497.86  ]
#  [-48254.36  ]
#  [-34565.84  ]
#  [  3740.9229]
#  [  3348.9001]
#  [  2341.8691]
#  [  2341.8691]
#  [-26622.607 ]
#  [  3004.8435]
#  [-31210.594 ]
#  [  3220.415 ]
#  [  4985.0166]
#  [  3089.849 ]
#  [  2792.3433]
#  [-23546.04  ]
#  [-31925.312 ]
#  [-17321.309 ]
#  [  2505.942 ]
#  [-21847.04  ]
#  [  3290.788 ]
#  [-28928.148 ]
#  [-22198.93  ]
#  [-37450.17  ]
#  [  2483.824 ]
#  [-25691.932 ]
#  [-27904.666 ]
#  [-49579.516 ]
#  [  1119.7847]
#  [-32310.234 ]
#  [  2594.5337]]
# [[ -7759.2373 ]
#  [  1045.7234 ]
#  [  2786.5144 ]
#  [-23217.824  ]
#  [  1846.7103 ]
#  [  2759.532  ]
#  [-17066.732  ]
#  [  1697.3899 ]
#  [ -6191.6064 ]
#  [ -9393.104  ]
#  [ -9393.104  ]
#  [-20432.9    ]
#  [  1594.4927 ]
#  [-10655.972  ]
#  [  1927.9645 ]
#  [  1598.8364 ]
#  [  1481.8698 ]
#  [-16893.744  ]
#  [-17218.47   ]
#  [  1704.3169 ]
#  [  1406.9636 ]
#  [-14301.048  ]
#  [ -7553.0806 ]
#  [-15014.864  ]
#  [-20996.408  ]
#  [-33857.156  ]
#  [  3688.704  ]
#  [-28021.83   ]
#  [-31709.143  ]
#  [  5432.0254 ]
#  [-31664.385  ]
#  [  1955.3558 ]
#  [  2249.6943 ]
#  [  2234.8843 ]
#  [-17859.629  ]
#  [-17859.629  ]
#  [  1996.0532 ]
#  [-24795.06   ]
#  [  1950.0289 ]
#  [  1369.1772 ]
#  [  1327.0625 ]
#  [-13111.33   ]
#  [-13128.126  ]
#  [-29988.908  ]
#  [  2659.8906 ]
#  [-15110.512  ]
#  [  1950.4952 ]
#  [-20058.605  ]
#  [-11037.509  ]
#  [  1555.162  ]
#  [  1621.8904 ]
#  [-15198.153  ]
#  [  1522.8813 ]
#  [  -559.6531 ]
#  [  1279.6254 ]
#  [-20789.994  ]
#  [  1708.5173 ]
#  [-12661.969  ]
#  [-13523.974  ]
#  [-20559.262  ]
#  [  2023.6165 ]
#  [-34489.05   ]
#  [-27666.28   ]
#  [  2922.9277 ]
#  [  2922.9277 ]
#  [-22653.816  ]
#  [   974.74536]
#  [  2325.9116 ]
#  [-20264.986  ]
#  [-16856.617  ]
#  [-30256.697  ]
#  [  2352.8274 ]
#  [-13407.995  ]
#  [  1796.1594 ]
#  [-14479.292  ]
#  [-11462.508  ]
#  [  1361.9948 ]
#  [ -9603.356  ]
#  [-13814.518  ]
#  [-11159.537  ]
#  [-10833.141  ]
#  [-11956.537  ]
#  [-14302.15   ]
#  [  1123.208  ]
#  [ -5284.331  ]
#  [ -8370.198  ]
#  [   741.69006]
#  [ -7783.2427 ]
#  [  1352.3412 ]
#  [  1165.834  ]
#  [  2207.7627 ]
#  [  1488.5737 ]
#  [  1735.6921 ]
#  [  3017.1182 ]
#  [-35956.55   ]
#  [-20510.305  ]
#  [-28203.484  ]
#  [  1668.0023 ]
#  [  1981.9702 ]
#  [-13481.515  ]
#  [-18857.42   ]
#  [-13508.081  ]
#  [  1461.8229 ]
#  [  1308.6243 ]
#  [   915.08655]
#  [   915.08655]
#  [-10403.943  ]
#  [  1174.1704 ]
#  [-12196.884  ]
#  [  1258.4136 ]
#  [  1948.0024 ]
#  [  1207.3898 ]
#  [  1091.1273 ]
#  [ -9201.651  ]
#  [-12476.188  ]
#  [ -6769.0884 ]
#  [   979.2045 ]
#  [ -8537.699  ]
#  [  1285.9147 ]
#  [-11304.927  ]
#  [ -8675.215  ]
#  [-14635.25   ]
#  [   970.5611 ]
#  [-10040.245  ]
#  [-10904.96   ]
#  [-19375.277  ]
#  [   437.50803]
#  [-12626.612  ]
#  [  1013.8254 ]]

# %%
len(features_set), train1.shape
# Out:
# (1435, (1435, 61))

# %%
X_train1 = train1[var1]
y_train1 = train1[target]
X_test1 = test[var1]
y_test1 = test[target]

model = ExtraTreesRegressor()
model.fit(X_train1, y_train1)
feature_importances = pd.DataFrame(model.feature_importances_, index=X_train1.columns, columns=['importance']).sort_values('importance', ascending=False)
feature_importances

# %%
X_train1 = train1[var1]
y_train1 = train1[target]
X_test1 = test[var1]
y_test1 = test[target]

model = ExtraTreesRegressor()
model.fit(X_train1, y_train1)
feature_importances = pd.DataFrame(model.feature_importances_, index=X_train1.columns, columns=['importance']).sort_values('importance', ascending=False)
feature_importances

# %%
X_train1 = train1[var1]
y_train1 = train1[target]
X_test1 = test[var1]
y_test1 = test[target]

model = ExtraTreesRegressor()
model.fit(X_train1, y_train1)
feature_importances = pd.DataFrame(model.feature_importances_, index=X_train1.columns, columns=['importance']).sort_values('importance', ascending=False)
feature_importances

# %%
X_train1 = train1[var1]
y_train1 = train1[target]
X_test1 = test[var1]
y_test1 = test[target]

model = ExtraTreesRegressor()
model.fit(X_train1, y_train1)
feature_importances = pd.DataFrame(model.feature_importances_, index=X_train1.columns, columns=['importance']).sort_values('importance', ascending=False)
feature_importances
